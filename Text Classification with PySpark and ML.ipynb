# %% [markdown]
# ### Text Classification with PySpark
# #### MultiClass Text Classification
#
# #### Task
# + predict the subject category given a course title or text
#
# #### Pyspark
# + pipenv install pyspark

# %%
import findspark
findspark.init()

# %%
# Load Pkgs
from pyspark import SparkContext

# %%
sc = SparkContext(master="local[2]")

# %%
# Launch UI
sc
# Out:
# <SparkContext master=local[2] appName=pyspark-shell>

# %%
# Create A Spark Session
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("TextClassifierwithPySpark").getOrCreate()

# %%
# Load Our Dataset
df = spark.read.csv("clean-datas/TwitterCleanData.csv",header=True,inferSchema=True)

# %%
df.show()
# Out:
# +---+--------------------+
# |_c0|       Cleaning_Data|
# +---+--------------------+
# |  0|อุบลจะจมบาดาลแล้ว...|
# |  1|อุบลจะจมบาดาลแล้ว...|
# |  2|สนใจงานออนไลน์หาร...|
# |  3|งั้นหอเตือนภัยก็ไ...|
# |  4|ที่ดันเเท็กกันอยู...|
# |  5|นี่คือบ้านของเราเ...|
# |  6|อุบลจะจมบาดาลแล้ว...|
# |  7|                null|
# |  8|เมื่อไหร่สำนักข่า...|
# |  9|น้องๆน่าสงสารมากก...|
# | 10|อุบลจะจมบาดาลแล้ว...|
# | 11|อุบลจะจมบาดาลแล้ว...|
# | 12|ฝากรีหน่อยค่ะคุณย...|
# | 13|น้ำท่วมอุบลวันนี้...|
# | 14|นี่คือบ้านของเราเ...|
# | 15|ย้ำตอนนี้น้ำไฟถูก...|
# | 16|ถูกตัดขาดคือแล้วย...|
# | 17|นี่คือบ้านของเราเ...|
# | 18|ไม่ใช่ทางม้าลายแต...|
# | 19|น้องๆน่าสงสารมากก...|
# +---+--------------------+
# only showing top 20 rows

# %%
# Columns
df.columns
# Out:
# ['_c0', 'Cleaning_Data']

# %%
# Select Columns
df.select('Cleaning_Data').show()
# Out:
# +--------------------+
# |       Cleaning_Data|
# +--------------------+
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
# |สนใจงานออนไลน์หาร...|
# |งั้นหอเตือนภัยก็ไ...|
# |ที่ดันเเท็กกันอยู...|
# |นี่คือบ้านของเราเ...|
# |อุบลจะจมบาดาลแล้ว...|
# |                null|
# |เมื่อไหร่สำนักข่า...|
# |น้องๆน่าสงสารมากก...|
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
# |ฝากรีหน่อยค่ะคุณย...|
# |น้ำท่วมอุบลวันนี้...|
# |นี่คือบ้านของเราเ...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |ถูกตัดขาดคือแล้วย...|
# |นี่คือบ้านของเราเ...|
# |ไม่ใช่ทางม้าลายแต...|
# |น้องๆน่าสงสารมากก...|
# +--------------------+
# only showing top 20 rows

# %%
df = df.select('Cleaning_Data')

# %%
df.show(5)
# Out:
# +--------------------+
# |       Cleaning_Data|
# +--------------------+
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
# |สนใจงานออนไลน์หาร...|
# |งั้นหอเตือนภัยก็ไ...|
# |ที่ดันเเท็กกันอยู...|
# +--------------------+
# only showing top 5 rows

# %%
# Value Counts
df.groupBy('Cleaning_Data').count().show()
# Out:
# +--------------------+-----+
# |       Cleaning_Data|count|
# +--------------------+-----+
# |อมกมีคนจมน้ำเสียช...|   37|
# |มันขนาดนี้แล้วอ่ะมึง|    1|
# |ขอโทษนะสื่อต่างๆเ...|    5|
# |ฝั่งเซนทรัลต้องนั...|   35|
# |วันนี้อากาศเย็นมา...|    3|
# |ช่วยช้างตกงานกันจ...|    1|
# |แกน้ำมันสูงมากจริ...|    2|
# |ฝากทุกคนด้วยนะคะใ...|    1|
# |ไม่แปลกที่หลายๆท่...|    1|
# |พี่หนุ่มเพจข่าวสา...|    1|
# |ตรรกะความคิดอิรัฐ...|    1|
# |บ้านชั้นถูกน้ำท่ว...|    1|
# |อย่าพึ่งให้แท็กจม...|    8|
# |นี่เป็นเด็กจากกทม...|    4|
# |สงสารพี่น้องชาวอุ...|    2|
# |ล่าสุดน้ำมูลสูงกว...|    2|
# |เข้าใจหรือยังว่าก...|    4|
# |น้ำท่วมในไทยทุกปี...|    2|
# |บังคับรีค่ะน้ำท่ว...|    1|
# |ยังมีน้องๆที่ต้อง...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %%
# Value Counts via pandas
df.toPandas()['Cleaning_Data'].value_counts()
# Out:
# น้ำท่วมอุบลวันนี้มีคนจมน้ำเสียชีวิตทีนี้จะออกข่าวได้ยังครับขอแสดงความเสียใจกับครอบครัวผู้สูญเสียนะครับน้ําท่วมอุบล          7356
# บ้านเราเองท่วมมาจะเป็นเดือนแล้วสื่อเงียบรัฐบาลเงียบเจ้าหน้าที่ทัองถิ่นเงียบประชาชนต้องช่วยเหลือกันเองแย่มากน้ําท่วม         5327
# ฝากรีทวิตช่วยชาวอุบลเราด้วยนะคะน้ำท่วมหนักสุดในรอบปีเลยน้ําท่วมอุบล                                                         4395
# นี่คือบ้านของเราเองครับถ่ายเมื่อเกือบสัปดาห์ก่อนน้ำยังขึ้นเรื่อยๆอยู่เลยอยากฝากโซเชียลเป็นกระบอกเสียงให้หน่วยงานเข้าช่วย    3107
# อุบลจะจมบาดาลแล้วช่วยพวกเราด้วยน้ําท่วมอุบล                                                                                 2981
#                                                                                                                             ...
# ตอนนี้ที่อุบลคือหนักมากๆลำบากกันมากๆรัฐบาลทำอะไรอยู่ไม่ใช่วันแรกมั้ยงงว่ะซื้ออาวุธใช้ภาษีประชาชนซื้อได้แต่ทีป                  1
# เห็นเเล้งจะร้องไห้ถ้าเป็นเราเราจะทำยังไงขอให้น้ำลดลงไวๆด้วยเถอะ                                                                1
# สายนักล่าเครดิตฟรีเครดิตฟรีกดติดตามกดรีทวิตกดหัวใจแคปรูปส่งให้แอดมินแจกจริงทักตรงนี้เ                                          1
# น้ําท่วมอุบลจะไปไหว้พญานาคงูใหญ่นาคราชองค์ดำบ่ได้                                                                              1
# นายกลงพื้นที่อุบลพอเขาไปก็หาว่าสร้างภาพอีกแล้วก็พูดแต่ว่าเขาไม่มาชวยมาดูมาแก้ไขน้ําท่วมอุบลก็จะบอกอีกว่าท่วมนาแล้วลำบา         1
# Name: Cleaning_Data, Length: 1824, dtype: int64

# %%
# Check For Missing Values
df.toPandas()['Cleaning_Data'].isnull().sum()
# Out:
# 232

# %%
# Drop Missing Values
df = df.dropna(subset=('Cleaning_Data'))

# %%
# Check For Missing Values
df.toPandas()['Cleaning_Data'].isnull().sum()
# Out:
# 0

# %%
df.show(100)
# Out:
# +--------------------+
# |       Cleaning_Data|
# +--------------------+
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
#
...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |นี่คือบ้านของเราเ...|
# |ใครที่กำลังมองหาร...|
# |น้ําท่วมอุบลอีสาน...|
# |น้องๆน่าสงสารมากก...|
# |ขอคนละรีช่วยกันดั...|
# |อุบลจะจมบาดาลแล้ว...|
# |น้องๆน่าสงสารมากก...|
# |ไม่ใช่แค่น้ำท่วมแ...|
# |น้องๆน่าสงสารมากก...|
# |คนต่างจังหวัดไม่ม...|
# |อุบลจะจมบาดาลแล้ว...|
# |ขอส่งกำลังใจให้ผู...|
# |พอเป็นภาคอีสานก็เ...|
# |ด่วนขณะนี้น้ำท่วม...|
# |ถ้ายังสนใจกันอยู่...|
# |ด่วนขณะนี้น้ำท่วม...|
# +--------------------+
# only showing top 100 rows

# %% [markdown]
# ### Feature Extraction
# #### Build Features From Text
# + CountVectorizer
# + TFIDF
# + WordEmbedding
# + HashingTF
# + etc

# %%
# Load Our Pkgs
import pyspark.ml.feature

# %%
dir(pyspark.ml.feature)
# Out:
# ['Any',
#  'Binarizer',
#  'BucketedRandomProjectionLSH',
#  'BucketedRandomProjectionLSHModel',
#  'Bucketizer',
#  'ChiSqSelector',
#  'ChiSqSelectorModel',
#  'CountVectorizer',
#  'CountVectorizerModel',
#  'DCT',
#  'DataFrame',
#  'DenseMatrix',
#  'DenseVector',
#  'Dict',
#  'ElementwiseProduct',
#  'FeatureHasher',
#  'Generic',
#  'HasFeaturesCol',
#  'HasHandleInvalid',
#  'HasInputCol',
#  'HasInputCols',
#  'HasLabelCol',
#  'HasMaxIter',
#  'HasNumFeatures',
#  'HasOutputCol',
#  'HasOutputCols',
#  'HasRelativeError',
#  'HasSeed',
#  'HasStepSize',
#  'HasThreshold',
#  'HasThresholds',
#  'HashingTF',
#  'IDF',
#  'IDFModel',
#  'Imputer',
#  'ImputerModel',
#  'IndexToString',
#  'Interaction',
#  'JM',
#  'JavaEstimator',
#  'JavaMLReadable',
#  'JavaMLWritable',
#  'JavaModel',
#  'JavaParams',
#  'JavaTransformer',
#  'List',
#  'MaxAbsScaler',
#  'MaxAbsScalerModel',
#  'MinHashLSH',
#  'MinHashLSHModel',
#  'MinMaxScaler',
#  'MinMaxScalerModel',
#  'NGram',
#  'Normalizer',
#  'OneHotEncoder',
#  'OneHotEncoderModel',
#  'Optional',
#  'P',
#  'PCA',
#  'PCAModel',
#  'Param',
#  'Params',
#  'PolynomialExpansion',
#  'QuantileDiscretizer',
#  'RFormula',
#  'RFormulaModel',
#  'RegexTokenizer',
#  'RobustScaler',
#  'RobustScalerModel',
#  'SQLTransformer',
#  'SparkContext',
#  'StandardScaler',
#  'StandardScalerModel',
#  'StopWordsRemover',
#  'StringIndexer',
#  'StringIndexerModel',
#  'TYPE_CHECKING',
#  'Tokenizer',
#  'Tuple',
#  'TypeConverters',
#  'TypeVar',
#  'Union',
#  'UnivariateFeatureSelector',
#  'UnivariateFeatureSelectorModel',
#  'VarianceThresholdSelector',
#  'VarianceThresholdSelectorModel',
#  'Vector',
#  'VectorAssembler',
#  'VectorIndexer',
#  'VectorIndexerModel',
#  'VectorSizeHint',
#  'VectorSlicer',
#  'Word2Vec',
#  'Word2VecModel',
#  '_BucketedRandomProjectionLSHParams',
#  '_CountVectorizerParams',
#  '_IDFParams',
#  '_ImputerParams',
#  '_LSH',
#  '_LSHModel',
#  '_LSHParams',
#  '_MaxAbsScalerParams',
#  '_MinMaxScalerParams',
#  '_OneHotEncoderParams',
#  '_PCAParams',
#  '_RFormulaParams',
#  '_RobustScalerParams',
#  '_Selector',
#  '_SelectorModel',
#  '_SelectorParams',
#  '_StandardScalerParams',
#  '_StringIndexerParams',
#  '_UnivariateFeatureSelectorParams',
#  '_VarianceThresholdSelectorParams',
#  '_VectorIndexerParams',
#  '_Word2VecParams',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_convert_to_vector',
#  '_jvm',
#  'cast',
#  'inherit_doc',
#  'keyword_only',
#  'overload',
#  'since']

# %%
# Load Our Transformer & Extractor Pkgs
from pyspark.ml.feature import Tokenizer,StopWordsRemover,CountVectorizer,IDF
from pyspark.ml.feature import StringIndexer

# %%
df.show(100)
# Out:
# +--------------------+
# |       Cleaning_Data|
# +--------------------+
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
# |สนใจงานออนไลน์หาร...|
# |งั้นหอเตือนภัยก็ไ...|
# |ที่ดันเเท็กกันอยู...|
# |นี่คือบ้านของเราเ...|
# |อุบลจะจมบาดาลแล้ว...|
# |เมื่อไหร่สำนักข่า...|
# |น้องๆน่าสงสารมากก...|
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
# |ฝากรีหน่อยค่ะคุณย...|
# |น้ำท่วมอุบลวันนี้...|
# |นี่คือบ้านของเราเ...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |ถูกตัดขาดคือแล้วย...|
# |นี่คือบ้านของเราเ...|
# |ไม่ใช่ทางม้าลายแต...|
# |น้องๆน่าสงสารมากก...|
# |งานดีรีวิวแน่นมาก...|
# |เหมือนพวกเราถูกลื...|
# |สนใจงานออนไลน์หาร...|
# |น้ำท่วมอุบลวันนี้...|
# |เหมือนพวกเราถูกลื...|
# |น้ำท่วมอุบลวันนี้...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |น้ำท่วมอุบลวันนี้...|
# |น้ำท่วมอุบลวันนี้...|
# |น้ําท่วมอุบลอีสาน...|
# |อุบลจะจมบาดาลแล้ว...|
# |ช่วยกันรีทวิตกระจ...|
# |อมกมีคนจมน้ำเสียช...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |นี่คือบ้านของเราเ...|
# |น้ำใกล้โรงพยาบาลเ...|
# |นี่คือบ้านของเราเ...|
# |สงสารทุกคนที่ได้ร...|
# |บ้านเราเองท่วมมาจ...|
# |อุบลจะจมบาดาลแล้ว...|
# |ถูกตัดขาดคือแล้วย...|
# |ส่วนทางเลือกเดียว...|
# |สนใจงานออนไลน์หาร...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |อุบลจะจมบาดาลแล้ว...|
# |นี่คือบ้านของเราเ...|
# |เมื่อไหร่สำนักข่า...|
# |อุบลจะจมบาดาลแล้ว...|
# |นี่คือบ้านของเราเ...|
# |การช่วยเหลือและบร...|
# |น้ำใกล้โรงพยาบาลเ...|
# |ดันหน่อยครับข่าวเ...|
# |นี่คือบ้านของเราเ...|
# |โหข่าวคราวดังได้น...|
# |น้ำท่วมอุบลวันนี้...|
# |ด่วนขณะนี้น้ำท่วม...|
# |เราควรโฟกัสน้ําท่...|
# |สนใจงานออนไลน์หาร...|
# |ช่วยกันรีทวิตกระจ...|
# |บ้านเราเองท่วมมาจ...|
# |นี่คือบ้านของเราเ...|
# |ช่วยกันดันแท็กนี้...|
# |โหข่าวคราวดังได้น...|
# |น้องๆน่าสงสารมากก...|
# |อุบลจะจมบาดาลแล้ว...|
# |ฝากรีหน่อยค่ะคุณย...|
# |สถานการณ์น้ําท่วม...|
# |แต่จริงข่าวอุบลเง...|
# |เหมือนพวกเราถูกลื...|
# |น้ําท่วมอุบลอีสาน...|
# |ไม่ใช่เรื่องที่คว...|
# |น้ำท่วมภาคอีสานคื...|
# |ช่วยกระจายข่าวขอใ...|
# |แต่จริงข่าวอุบลเง...|
# |อุบลจะจมบาดาลแล้ว...|
# |น้ำท่วมอุบลวันนี้...|
# |นี่คือบ้านของเราเ...|
# |แต่จริงข่าวอุบลเง...|
# |ทำไมน้ําท่วมอุบลถ...|
# |น้ำท่วมอุบลวันนี้...|
# |อุบลจะจมบาดาลแล้ว...|
# |โห๋น้ำท่วมสูงจิงจ...|
# |น้ำท่วมภาคอีสานคื...|
# |ช่วยกันรีทวิตกระจ...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |นี่คือบ้านของเราเ...|
# |ใครที่กำลังมองหาร...|
# |น้ําท่วมอุบลอีสาน...|
# |น้องๆน่าสงสารมากก...|
# |ขอคนละรีช่วยกันดั...|
# |อุบลจะจมบาดาลแล้ว...|
# |น้องๆน่าสงสารมากก...|
# |ไม่ใช่แค่น้ำท่วมแ...|
# |น้องๆน่าสงสารมากก...|
# |คนต่างจังหวัดไม่ม...|
# |อุบลจะจมบาดาลแล้ว...|
# |ขอส่งกำลังใจให้ผู...|
# |พอเป็นภาคอีสานก็เ...|
# |ด่วนขณะนี้น้ำท่วม...|
# |ถ้ายังสนใจกันอยู่...|
# |ด่วนขณะนี้น้ำท่วม...|
# +--------------------+
# only showing top 100 rows

# %%
# Stages For the Pipeline
tokenizer = Tokenizer(inputCol='Cleaning_Data',outputCol='mytokens')
stopwords_remover = StopWordsRemover(inputCol='mytokens',outputCol='filtered_tokens')
vectorizer = CountVectorizer(inputCol='filtered_tokens',outputCol='rawFeatures')
idf = IDF(inputCol='rawFeatures',outputCol='vectorizedFeatures')

# %%
# LabelEncoding/LabelIndexing
labelEncoder = StringIndexer(inputCol='Cleaning_Data',outputCol='label').fit(df)

# %%
labelEncoder.transform(df).show(100)
# Out:
# +--------------------+------+
# |       Cleaning_Data| label|
# +--------------------+------+
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |สนใจงานออนไลน์หาร...| 535.0|
# |งั้นหอเตือนภัยก็ไ...|  44.0|
# |ที่ดันเเท็กกันอยู...| 601.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |เมื่อไหร่สำนักข่า...|  12.0|
# |น้องๆน่าสงสารมากก...|   5.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |ฝากรีหน่อยค่ะคุณย...|  78.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |ย้ำตอนนี้น้ำไฟถูก...|  10.0|
# |ถูกตัดขาดคือแล้วย...|  27.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |ไม่ใช่ทางม้าลายแต...|  11.0|
# |น้องๆน่าสงสารมากก...|   5.0|
# |งานดีรีวิวแน่นมาก...| 707.0|
# |เหมือนพวกเราถูกลื...|  33.0|
# |สนใจงานออนไลน์หาร...| 535.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |เหมือนพวกเราถูกลื...|  33.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |ย้ำตอนนี้น้ำไฟถูก...|  10.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |น้ําท่วมอุบลอีสาน...|  24.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |ช่วยกันรีทวิตกระจ...|  37.0|
# |อมกมีคนจมน้ำเสียช...| 125.0|
# |ย้ำตอนนี้น้ำไฟถูก...|  10.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |น้ำใกล้โรงพยาบาลเ...|  49.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |สงสารทุกคนที่ได้ร...|1460.0|
# |บ้านเราเองท่วมมาจ...|   1.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |ถูกตัดขาดคือแล้วย...|  27.0|
# |ส่วนทางเลือกเดียว...| 329.0|
# |สนใจงานออนไลน์หาร...| 535.0|
# |ย้ำตอนนี้น้ำไฟถูก...|  10.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |เมื่อไหร่สำนักข่า...|  12.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |การช่วยเหลือและบร...| 163.0|
# |น้ำใกล้โรงพยาบาลเ...|  49.0|
# |ดันหน่อยครับข่าวเ...|  29.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |โหข่าวคราวดังได้น...|  88.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |ด่วนขณะนี้น้ำท่วม...|  20.0|
# |เราควรโฟกัสน้ําท่...|  35.0|
# |สนใจงานออนไลน์หาร...| 535.0|
# |ช่วยกันรีทวิตกระจ...|  37.0|
# |บ้านเราเองท่วมมาจ...|   1.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |ช่วยกันดันแท็กนี้...|  16.0|
# |โหข่าวคราวดังได้น...|  88.0|
# |น้องๆน่าสงสารมากก...|   5.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |ฝากรีหน่อยค่ะคุณย...|  78.0|
# |สถานการณ์น้ําท่วม...| 145.0|
# |แต่จริงข่าวอุบลเง...|  17.0|
# |เหมือนพวกเราถูกลื...|  33.0|
# |น้ําท่วมอุบลอีสาน...|  24.0|
# |ไม่ใช่เรื่องที่คว...|  84.0|
# |น้ำท่วมภาคอีสานคื...|  32.0|
# |ช่วยกระจายข่าวขอใ...|  21.0|
# |แต่จริงข่าวอุบลเง...|  17.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |แต่จริงข่าวอุบลเง...|  17.0|
# |ทำไมน้ําท่วมอุบลถ...|  43.0|
# |น้ำท่วมอุบลวันนี้...|   0.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |โห๋น้ำท่วมสูงจิงจ...| 215.0|
# |น้ำท่วมภาคอีสานคื...|  32.0|
# |ช่วยกันรีทวิตกระจ...|  37.0|
# |ย้ำตอนนี้น้ำไฟถูก...|  10.0|
# |นี่คือบ้านของเราเ...|   3.0|
# |ใครที่กำลังมองหาร...|1783.0|
# |น้ําท่วมอุบลอีสาน...|  24.0|
# |น้องๆน่าสงสารมากก...|   5.0|
# |ขอคนละรีช่วยกันดั...|  34.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |น้องๆน่าสงสารมากก...|   5.0|
# |ไม่ใช่แค่น้ำท่วมแ...|  14.0|
# |น้องๆน่าสงสารมากก...|   5.0|
# |คนต่างจังหวัดไม่ม...|  66.0|
# |อุบลจะจมบาดาลแล้ว...|   4.0|
# |ขอส่งกำลังใจให้ผู...| 109.0|
# |พอเป็นภาคอีสานก็เ...|  51.0|
# |ด่วนขณะนี้น้ำท่วม...|  20.0|
# |ถ้ายังสนใจกันอยู่...| 290.0|
# |ด่วนขณะนี้น้ำท่วม...|  20.0|
# +--------------------+------+
# only showing top 100 rows

# %%
labelEncoder.labels
# Out:
# ['น้ำท่วมอุบลวันนี้มีคนจมน้ำเสียชีวิตทีนี้จะออกข่าวได้ยังครับขอแสดงความเสียใจกับครอบครัวผู้สูญเสียนะครับน้ําท่วมอุบล',
#  'บ้านเราเองท่วมมาจะเป็นเดือนแล้วสื่อเงียบรัฐบาลเงียบเจ้าหน้าที่ทัองถิ่นเงียบประชาชนต้องช่วยเหลือกันเองแย่มากน้ําท่วม',
#  'ฝากรีทวิตช่วยชาวอุบลเราด้วยนะคะน้ำท่วมหนักสุดในรอบปีเลยน้ําท่วมอุบล',
#  'นี่คือบ้านของเราเองครับถ่ายเมื่อเกือบสัปดาห์ก่อนน้ำยังขึ้นเรื่อยๆอยู่เลยอยากฝากโซเชียลเป็นกระบอกเสียงให้หน่วยงานเข้าช่วย',
#  'อุบลจะจมบาดาลแล้วช่วยพวกเราด้วยน้ําท่วมอุบล',
#  'น้องๆน่าสงสารมากกกกกขอบคุณพี่ๆที่เข้าไปช่วยจริงๆส่วนแท็กก็แมสเถอะอุบลแทบจะใช้เรือสัญจรแทนรถแล้วน้ําท่วมอุบล',
#  'มันหดหู่จริงๆนะที่เห็นชาวบ้านได้แต่นั่งมองหลังคาบ้านตัวเองกำลังจ่มน้ำลงเรื่อยๆข่าวเงียบมากจะไม่ทำอะไรช่วยเราเลยจริงๆหรออ',
#  'นี้คือบรรยากาศค่ายอพยพน้ําท่วมอุบลครับเต็นท์ต่อครอบครัวย้ายเต็นท์ครั้งเพราะคาดการณ์ระดับน้ำผิดห้องน้ำไ',
#  'ฝากรีกระจายข่าวค่ะตอนนี้น้ำท่วมอุบลหนักมากชาวบ้านเดือดร้อนเป็นกระบอกเสียงให้ชาวอุบลกันนะคะน้ําท่วมอุบลฝากแท็ก',
#  'ก็มันชื่อหอเตือนภัย',
#  'ย้ำตอนนี้น้ำไฟถูกตัดขาดแล้วและอาจเป็นเมืองบาดาลได้เลยย้ำตอนนี้น้ำไฟถูกตัดขาดแล้วและอาจเป็นเมืองบาดาลได้เลยย้ำ',
#  'ไม่ใช่ทางม้าลายแต่มันคือหลังคาบ้านที่จมน้ำน้ําท่วมอุบล',
#  'เมื่อไหร่สำนักข่าวต่างๆจะเลิกปิดข่าวน้ำท่วมอุบลเอ่ยน้ำมากกว่าปีแต่ข่าวเท่าขี้แมวอุบลจะกลายเป็นเมืองบาดาลแล้วคับเด็ก',
#  'สรุปสถานการณ์น้ําท่วมอุบลระดับน้ำเพิ่มสูงขึ้นเรื่อยๆน้ำมากสุดรอบปีน้ำเข้าห้างชั้นอุบลแล้วเห',
#  'ไม่ใช่แค่น้ำท่วมแต่คือน้ำเชี่ยวมากบ้านเรือนที่อยู่ละแวกนี้คือไม่มิดหลังคาก็เกินชั้นสองของบ้านแล้วค่ะตอนนี้ฝนตกทุกวันมวล',
#  'ใครคิดภาพน้ำท่วมอุบลไม่ออกรูปที่เห็นนี่แค่อำเภอที่ติดกันแล้วตอนนี้ท่วมเกือบทุกอำเภออ่ะในส่วนตัวเมืองยังขนาด',
#  'ช่วยกันดันแท็กนี้หน่อยนะคะตอนนี้น้ำจะถึงโรงพยาบาลแล้วค่ะน้ําท่วมอุบล',
#  'แต่จริงข่าวอุบลเงียบมากอะเซนทรัลที่สร้างถมดินสูงตอนนี้คือแทบไม่มีคนเพราะน้ำท่วมรอบๆหมดเลยฝั่งเมืองไปวารินเหลือเส้นเดียวแต่',
#  'ข่าวน้ําท่วมอุบลเงียบมากคือไม่ดังเลยสงสารจังเลยค่ะขอให้ทุกคนปลอดภัยนะคะ',
#  'อัพเดทหน้าบ้านวันนี้สูงเลยหัวแม่แล้วจ้าฟฟฟฟฟฟน้ําท่วมอุบลอันนั้นคุณน้าเรือรับจ้างนะฮะ',
#  'เราควรโฟกัสน้ําท่วมอุบลมากกว่าข่าวโตโน่',
#  'โห๋ผ่านไปวันท่วมมากกว่าเดิมน้ําท่วมอุบล',
#  'ช่วยกันรีทวิตกระจายข่าวหน่อยนะคะชาวบ้านเดือดร้อนกันเยอะมากน้ําท่วมอุบลน้ําท่วมอุบล',
#  'น้ำท่วมราษีไศลน่าน้อยใจที่ศรีสะเกษถูกมองข้ามราษีไศลเป็นเกาะไปแล้วค่ะน้ำท่วมราษีไศลน้ําท่วมศรีสะเกษน้ําท่วมอุบล',
#  'ด่วนกำแพงกั้นน้ำดูโฮมอุบลแตกน้ำทะลักเข้าห้างซมเร่งดับไฟเข้าช่วยเหลือพนักงานนับร้อยชีวิตน้ําท่วมอุบล',
#  'นี่เป็นภาพการช่วยเหลือสุนัขที่ติดเกาะหลังจากน้ำท่วมจอุบลราชธานีเป็นเวลานานจากที่เห็นคือชาวบ้านจะต้องช่วยเหลือสุนัขเห',
#  'มายก้อดดดดดน้ำมาเร้วมากกกกเส้นนี้มีทั้งโรงพยาบาลสรรพสิทธิ์ทั้งศูนย์ไตเทียมทั้งวิทลัยพยาบาลถัดมาก็สนามบินน้ําท่วมอุบ',
#  'ขอรบกวนพื้นที่ฝากร้านคุณยายทีนะคะแวะดูแวะชมเป็นกำลังใจกันค่ะคุณยายพูดน่ารักมากน้ําท่วมอุบลคุณชายโป๊ปเบลล่า',
#  'ทำไมน้ําท่วมอุบลถึงต้องเฝ้าระวังสูงตามแผนที่เลยน้ำจากแทบจะทั้งภาคอีสานจะไหลมารวมกันที่เมืองอุบลราชธานีเมืองวารินชำราบ',
#  'งั้นหอเตือนภัยก็ไร้ประโยชน์',
#  'ก็รัฐไม่ช่วยคนขับรถลากโต้หลังถูกโวยเรียกเก็บเงินพาข้ามน้ำท่วมบาทเผยโดนขอให้มาช่วยเหลือแต่ซื้อน้ำมันเองเพราะ',
#  'ทำไมเสียงของคนตจวถึงไม่ดังเท่ากรุงเทพทำไมพวกเขาถึงไม่ได้รับการช่วยเหลือที่ดีพอจากรัฐบาลดันแท็กให้รับรู้กันเยอะๆนะคะตอนนี้',
#  'มีสุนัขอีกตัวที่ติดเกาะต้องใช้เรือข้ามไปให้อาหารพบลูกสุนัขตายตัวและมีอีกครัวเรือนที่ติดเกาะหากผู้ใดอยากเข้ามาช่ว',
#  'ตอนนี้น้ำทะลักจะถึงรพสรรพสิทธิ์แล้วอ่ะผู้ป่วยแย่แน่ๆชาวบ้านอีกแล้วคือน้ำจะทะลักเข้ามากลางเมืองเลยจะเป็นบาดาลจริงๆแล้วนะ',
#  'น้ำใกล้โรงพยาบาลเข้ามาทุกวันถ้าท่วมโรงพยาบาลเมื่อไหร่อันนั้นคือสุดๆแล้วค่ะรพสรรพสิทธิ์เป็นรพศูนย์อีสานใต้ผู้ป่วยนอกจั',
#  'บ้านเราที่อุบลค่ะน้ำท่วมถึงหน้าต่างชั้นสองย้ำว่าชั้นคาดว่าวันนี้จะขึ้นมาอีกเรื่อยๆญาติๆต้องไปนอนวัดพิกัดหาดวัดใต้',
#  'พอเป็นภาคอีสานก็เหมือนถูกทิ้งให้ดูแลกันเองอะเป็นแบบนี้มาตลอดอย่างตั้งใจลืมไปแล้วว่าพวกเราก็เป็นส่วนหนึ่งของประเทศเหมือน',
#  'สวนสัตว์อุบลราชธานีตอนนี้กลายเป็นทะเลสาปไปแล้วน้ําท่วมอุบลน้ําท่วม',
#  'น้ําท่วมอุบลปีนี้หนักมากผมมาทำข่าววันแล้วบางจุดท่วมลึกเมตรเลยชั้นของบ้ายถึงขอบหน้าต่างชั้นก็มีสํานักข่าววั',
#  'อำเภอพิบูลย์มังสาหารก็ท่วมหนักมาหลายวันชาวบ้านจัดงานระดมเงินช่วยเหลือกันเองภาครัฐทำอะไรอยู่ข่าวก็เงียบท่วมท่วมพิบูลย์มั',
#  'น้ำเต็มพื้นที่แล้วจริงๆรอบนอกตัวเมืองบ้านริมน้ำจมบาดาลไปแล้วตอนนี้น้ำกำลังเอ่อล้นเข้าตัวเมืองอาจจะท่วมสถานที่สำคัญๆอาทิ',
#  'วันเกิดปีนี้เรากับเพื่อนจะบริจาคเงินสดสมทบทุนช่วยเหลือผู้ประสบภัยน้ําท่วมอุบลนะคะสามารถบริจาคโดยตรงตาม',
#  'อุบลฯมีอำเภอน้ำท่วมไปแล้วอำเภอรัฐฯอยู่ไหนสนใจได้ยังน้ําท่วมอุบล',
#  'ถ้าใครคิดภาพไม่ออกว่ามันขนาดไหนน้ําท่วมอุบล',
#  'ไม่ต้องเตือนทุกวันทิพานันโวยพิธาระบุหอเตือนภัยชุมชนกุดแสนตอจอุบลราชธานีไม่แจ้งเตือนภัยมีแต่เปิดเพลงชาติทุก',
#  'ข่าวแทบทุกช่องที่ดูมีข่าวอุบลฯน้อยมากส่วนใหญ่ก็มีแต่ภาคกลางกับกลัวจะท่วมกทมแล้วอุบลฯล่ะท่วมมาเกือบเดือนแถมหนักด้วยแท',
#  'คืองงมากมีคนจากเทศบาลน่าจะอสมมาตะโกนบอกว่าให้เอาเอกสารไปยื่นลงชื่อรับเยียวยาทั้งๆที่บ้านเราน้ำท่วมชั้นจะถึงชั้นแล้ว',
#  'ขอประชาสัมพันธ์นะคะใครพบเห็นแจ้งได้ตามรายละเอียดข้างล่างนี้ได้เลยนะคะน้ําท่วมนนทบุรีน้ําท่วมอุบล',
#  'จบพับไมค์สวัสดีน้ําท่วมอุบลน้ำท่วมนนทบุรีน้ำท่วม',
#  'ตอนนี้น้ำทะลักจะถึงรพสรรพสิทธิ์แล้วผู้ป่วยชาวบ้านคือแย่จริงๆแล้วน้ำทะลักเข้ามากลางเมืองตอนนี้เกือบจะเป็นบาดาลแล้วรัฐบาล',
#  'เอาจริงๆนะข่าวน้ำท่วมอุบลเราเองก็เห็นข่าวจากในทวีตก่อนเลยลองๆเข้าไปดูในหน้าข่าวอื่นๆก็แทบไม่มีการนำเสนอข่าวเลยก็ไม่',
#  'คนต่างจังหวัดไม่มีหัวใจหรอไม่เดือดร้อนหรอน้ำท่วมกทมวันสองวันจะเป็นจะตายทีต่างจังหวัดรับน้ำให้พวกคุณทุกปีปีนึงหลาย',
#  'ในฐานะเด็กเตรียมสอบคนหนึ่งแค่อ่านหนังสือทำโจทย์ก็เหนื่อยจะแย่แล้วนี่เด็กซิ่วที่อุบลเค้าต้องทำยังไงอ่ะอ่านหนั',
#  'ฝากด้วยนะคับทุกคนตอนนี้น้ําท่วมอุบลกำลังสาหัสนะคับช่วยกันดักแท็กด้วยนะคับ',
#  'เกมใหม่มาแรงตอนนี้แจกเครดิตฟรีไม่ต้องแชร์กดติดตามกดรีทวิตแคปส่งแอดมินไปรับเครดิตฟรี',
#  'ระดับน้ำสูงขึ้นทุกวันรัฐบาลก็ยังคงแก้ปัญหาไม่ได้อยู่ดีอยู่ต่างจังหวัดภาษีก็ต้องจ่ายเวลาได้รับอุทกภัยก็ต้องช่วยเหลือตัวเอง',
#  'น้ําท่วมอุบลควรขึ้นได้แล้วคือหนักมากกก',
#  'สาหัสหนองปลากดอป่าโมกจอ่างทองน้ำสูงและคันดินแตกจุดเดิมปีที่แล้วทะลักเข้าท่วมเส้นอ่างทองอยุธยาสายในน้ํ',
#  'สื่อประเทศไทยหยุดเล่นข่าวดาราคนนั้นจะว่ายน้ำข้ามโขงแล้วมาช่วยกระจายข่าวอุบลแทบจะจมอยู่ใต้บาดาลก่อนไหมช่วยชาวบ้านที่ตอนนี้',
#  'มาสนใจน้ําท่วมอุบลเถอะครับพี่น้องชาวไทยอุบลจะเป็นเมืองบาดาลแล้วจ้าท่วมมานานแล้วจ้าฝนก็ตกเรื่อยๆน้ำก็สูงขึ้นเรื่อยๆจากอำ',
#  'เพราะผมไล่จากอุบลมาศรีสะเกษมาสุรินทร์มาบุรีรัมย์ขึ้นมาดูขอนแก่นเกรงว่าอุบลจะยังต้องการความช่วยเหลือต่อเนืองอีกสักพักค',
#  'อีสานน้ำท่วมหนักหลายจมากจริงๆแต่ก็เงียบมากเช่นกันการเข้าช่วยเหลือของหน่วยงานล่าช้าเข้าถึงก็ลำบากมากด้วยถนนหลายสายรถวิ่งไม่',
#  'ทั้งหล่อและมีน้ำใจแพทริคณัฐวรรธ์ฟิงค์เลอร์และแฟนคลับร่วมบริจาคช่วยเหลือผู้ประสบอุทกภัยอุบลราชธานีจำนวน',
#  'ฝากรีหน่อยค่ะคุณยายโดนรถชนกระเด็นลงในสวนข้างทางเสียชีวิตแต่คนขับหลบหนีสภาพศพของคุณยายคอหักขาหักผิดรูป',
#  'ถนนเส้นสุดท้ายที่เข้าออกเมืองอุบลราชธานีแต่อีกไม่นานมันก็คงจะตัดขาดเพราะน้ำปริ่มถนนมาวันแล้วน้ําท่วมอุบลน้ําท่วม',
#  'ปัญหาน้ำท่วมหนักในปีแต่กลับเป็นข่าวที่เงียบคำตอบของผู้นำก็แย่มากตอบแบบไม่มีสมองคิดในจะส่วนของรัฐประจำจังหวัดเองไม่มาดูแลป',

#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะแค่นาทีเค้ามีงานมาแนะนำทำง่ายๆค่ะได้เงินจริงทุกแพตฟอมงานไม่มีค่าสมัครไม่',
#  'กระจายข่าวอุบลตอนนี้วิกฤตแล้วค่ะนํ้าท่วมถึงหน้าร้านพิซซ่าระยะทางห่างจากโรงพยาบาลสรรพสิทธิประสงค์แค่นี้เองแต่ข่าว',
#  'น้ําท่วมอุบลครั้งประวัติศาสตร์เลยนะเงียบขนาดนี้ได้ไงวะ',
#  'รัฐบาลโปรดรับรู้ด้วยครับผมไม่ใช่เงือกเข้าออกมารับของแจกถุงยังชีพแต่ละทีเสียเงินวันละเลยเยียวยาเรื่องเงินด้วยนะรัฐบาล',
#  'ตอนนี้น้ำเริ่มซึมทะลักตามท่อเข้ามาในตัวเมืองแล้วน้ำจากขอนแก่นจะมาอีกน้ำเก่ายังไม่ลดน้ำใหม่ก็กำลังมาเพิ่มช่วย',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะแค่นาทีเค้ามีงานมาแนะนำทำง่ายๆค่ะได้เงินจริงทุกแพตฟอมงานไม่มีค่าสมัครไม่ต้',
#  'ท่วมหนักจริงนะปีนี้ระดับน้ำเพิ่มขึ้นทุกวันถนนที่จะเดินทางข้ามมาอำเภอเมืองก็ใกล้จะท่วมแล้วแต่คนนอกพื้นที่ไม่ค่อยรู้กันเลย',
#  'ฝากแชร์เป็นกระบอกเสียงทีค้าบลูกชาวอุบลกับชาวศรีสะเกษน้ำท่วมหนักมากๆน้ําท่วมอุบลน้ําท่วมศรีสะเกษ',
#  'เงินใช้คนชอบห้ามพลาดอยู่บ้านก็มีเงินเข้าบัญชีแล้วเพลงละบาทคลิปละบาทโฆษณาละบาทแบนน้ําท่วมอุ',
#  'น้ำท่วมอุบลในรอบปีแต่ข่าวเงียบมากน้ําท่วมอุบล',
#  'รีทวิตกระบอกเสียงรีทวิตกระบอกเสียงย้ำตอนนี้น้ำไฟถูกตัดขาดแล้วและอาจเป็นเมืองบาดาลได้เลย',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะแค่นาทีเค้ามีงานมาแนะนำทำง่ายๆค่ะงานไม่มีค่าสมัครไม่ผิดกฏหมายไม่ใช่การพนัน',
#  'ขอส่งกำลังใจให้ผู้ได้รับผลกระทบจากน้ำท่วมน้ําท่วมอุบลและในทุกจังหวัดเลยนะคะเมื่อวานไปทำงานอ่างทองอยุธยาก็ตกใจมาก',
#  'เครดิตฟรีรีทวิตหัวใจคอมเมนแจกจริงแคปส่งงานแอดมินเบอร์ที่สมัครสมัครเ',
#  'เตรียมรับมือใกล้ถึงเวลาอย่ามัวแต่แซะผู้ว่าน้ำท่วมบ้านจะตายห่าเอาเวลาปากเสียดูแลตัวเองมีอีกเยอะที่ผู้ว่าดูแลน้ําท่วมก',
#  'เว็บใหม่มาแรงแตกหนักแจกจริงสมัครตอนนี้รับทันทีคลิกเลยน้ําท่วมนนทบุรี',
#  'เงินใช้คนชอบห้ามพลาดอยู่บ้านก็มีเงินเข้าบัญชีแล้วเพลงละบาทคลิปละบาทโฆษณาละบาทแบนน้ําท่วมอุบล',
#  'จมแล้วช่วยพี่น้องชาวอุบลฯด้วยขออนุญาตใช้แท็กอิงล็อตน้ำท่วมอุบล',
#  'น้ําท่วมอุบลน้ําท่วมอุบล',
#  'หลังจากขึ้นศาลร่วมกันผมและเดินทางข้ามฝั่งมาขึ้นรถไฟให้ทันเวลาเพราะถนนตัดขาดไปหลายเส้นทางถ้ารถยนต์ไม่ทันแ',
#  'เครดิตฟรีเครดิตฟรีถอนได้เงินจริงคลิกมาโลยยเงื่อนไขการรับเครดิตฟรีกดติดตามกดหัวใจรีทวิตคอมเม้นแจก',
#  'ในขณะที่ชาวอุบลกำลังต้องการความช่วยเหลือจากทุกภาคส่วนโดยเฉพาะรัฐบาลมากที่สุดสปายรบกวนทุกคนช่วยกระจายข่าวนี้หน่อยนะคะ',
#  'ให้ความสนใจกับแท็กนี้หน่อยค่ะน้ำมาเยอะกว่าเมื่อวานอีกออกข่าวได้รึยังคะอีกนิดจะถึงรพสรรพสิทธิ์แล้วน้ําท่วมอุบล',
#  'ช่วยคนอุบลกันนะคะน้ําท่วมอุบลเรื่องเงียบมากน้ำสูงมากๆขาดแคลนน้ำคื่มช่วยแชร์กันนะคะ',
#  'น้องบินไปทำงานเมื่อวันที่น้ําท่วมอุบลหนักมากจริงๆ',
#  'น้ําท่วมอุบลน้ําท่วมอุบลนี้ชั้นบ้านน้าเราคือเก็บไม่ไหวแล้วต้องปล่อยจม',
#  'ฝากรีค่ะเส้นทางการจราจรแต่ละส่วนแต่ละพื้นที่ค่ะเดินทางไปไหนตรวจเช็คเส้นทางก่อนและเดินทางยังปลอดภัยนะคะน้ําท่วมอุบลน้ํา',
#  'รับคนปั่นยอดวิวมีเน็ตว่างงานใครก็ทำได้ค่าเพลงละบาทคลิปละบาทโฆษณาละบาทแบนมิลลิน้ําท่วมอุบลมิวศุภ',
#  'ศรีสะเกษก็หนักมากน้ำท่วมหนักมากในรอบปีหนักสุดปีและน้ำจากศรีสะเกษจะไหลไปที่ปลายทางอุบลราชธานีเป็นสถานีสุดท้ายจาก',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะเค้ามีงานมาแนะนำทำง่ายค่ะแค่นาทีสนใจเดมมาค่ะหมากปริญเตนิ',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะเค้ามีงานมาแนะนำทำง่ายค่ะแค่นาทีสนใจเดมมาค่ะแบนมิลลิน้ําท่วมนนทบุรีน้ํา',
#  'หมู่บ้านที่ถูกลืมจมลึกถึงเมตรตอนนี้แทบจะเป็นเมืองบาดาลแล้วรัฐมัวทำอะไรอยู่นี่มันขั้นวิกฤตแล้วไม่ควรปล่อยเบลอมาจนถึงตอน',
#  'หาคนบริจาคเลือดกรุ๊ปที่โรงพยาบาลพรรษาอุบลหน่อยค่ะต้องการใช้เลือดด่วนมากค่ะขอบคุณค่ะโรงพยาบาล๕๐',
#  'เกินต้านนาทีน้ำทะลักห้างดูโฮมจอุบลฯพนักงานใจสู้ไม่ทิ้งห้างขออยู่อุดจุดรั่วน้ําท่วมอุบลอุบลไทยรัฐออนไล',
#  'แพทองธารหนครอบครัวเพื่อไทยชื่นชมชาวบ้านอยุธยาปรับตัวอยู่น้ำท่วมกำลังใจยังดีแต่อยากให้รัฐเร่งช่วยเหลือเยียวยา',
#  'ช่วยกันดันแท็กน้ําท่วมอุบลเยอะๆนะคะตอนนี้มีแค่ประชาชนที่ต้องช่วยกันเองและคอยเป็นกระบอกเสียงให้กันเพราะรัฐบาลมันไม่คิด',
#  'ที่น่าสงสารที่สุดคือพี่น้องประชาชนที่นอนกางเตนท์นอนอยู่ๆน้ำมารองเท้าลอยหายไปกับน้ำตอนนี้ลมหนาวพัดเข้ามาแล้วเข้าใกล้',
#  'ผิดเพี้ยนกันไปหมดทำไมไม่คิดว่าตัวเองไม่มีประโยชน์บ้างอ่ะหอเตือนไม่ต้องเตือนก็ได้เหรอน้ําท่วมอุบลน้ําท่วมนนท',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไห
#  'ผมขอเป็นส่วนหนึ่งส่งกำลังให้พี่บิณฑ์และทีมงานช่วยพี่น้องชาวอุบลที่โดนน้ำท่วมอยู่ขณะนี้ครับหวังว่าปีนี้พี่บิณฑ์คงจะไ',
#  'รีทวิตช่วยกันกระจายช่องทางการช่วยเหลือค่ะช่องทางบริจาคสมทบทุนจุดรับบริจาคสิ่งของลงทะเบียนสำหรับ',
#  'อยากกลับบ้านแต่กลับไม่ได้น้ําท่วมอุบล',
#  'อยู่ในประเทศที่ประชาชนต้องมาขอความช่วยเหลือกันเองแล้วจะมีรัฐบาลไปทำไมในเมื่อมีก็เหมือนไม่มีบางบ้านน้ำท่วมจะเป็นเดือนแล้ว',
#  'เงินใช้คนชอบห้ามพลาดอยู่บ้านก็มีเงินเข้าบัญชีแล้วเพลงละบาทคลิปละบาทโฆษณาละบาทแบน',
#  'ใครที่กำลังมองหารายได้เสริมมาทางนี้โอนจ่ายทุกวันค่ะไม่เสียค่าสมัครไม่ใช่การพนันสนใจคลิกลิงค์ที่หน้าโปร์ไฟล์ทักมาค่',
#  'ขอฝากประชาสัมพันธ์ด้วยนะคะน้ําท่วมอุบล',
#  'คำถามหอเตือนภัยรัฐมีไว้ใช้ทำอะไรแจ้งเตือนภัยเปิดเพลงคำตอบง่ายมากๆครับคุณผู้อ่าน',
#  'ทำไมข่าวโตโน่ดังกว่าน้ําท่วมอุบลหนูคะอุบลคือวิกฤตมากแต่คนต่างภาคไม่ค่อยรู้ไม่เป็นข่าวช่วยสนใจหน่อยค่าาา',
#  'ท่วมหนักจนชั้นสองของบ้านก็ไม่รอดแล้วค่ะข้าวของเครื่องใช้ก็จมไปกับนํ้าหมดแล้วรัฐบาลอยู่ไหนเอ่ยน้ําท่วมอุบลน้ําท่ว',
#  'นอกจากน้ําท่วมอุบลตอนนี้น้ำเจ้าพระยาทำผนังเขื่อนริมตลิ่งแตกไหลเข้าบ้านประชาชนในตอินทร์บุรีน้ำท่วมอินทร์บุรีน้ำ',
#  'น้ำท่วมอุบลครั้งนี้ไม่ใช่แค่คนที่ได้รับผลกระทบแม้กระทั่งสัตว์ก็ได้รับผลกระทบเช่นเดียวกันสู้ไปนำกันนี่ละเนาะลูกเอ๊ยเฮ็ดไ',
#  'น้ําท่วมอุบลท่วมชั้นแล้วถึงเอวเลย',
#  'มีงานมาแนะนำค่ะอยู่ที่ไหนก็ทำได้ค่ะขอเเค่มีมือถือเน็ตงานถูกกฏหมายสนใจเดมมาเลยคะเปิดวิกต้นปีมีลั่นกันอรรถ',
#  'รับคนปั่นยอดวิวมีเน็ตว่างงานเดมมาคะเพลงละบาทคลิปละบาทโฆษณาละบาทน้ําท่วมอุบลหม้อไฟแห่งความสุข',
#  'รายงานสถานการณ์ล่าสุดวันที่ตุลาคมโดยสสเปิ้ลกิตติ์ธัญญาวาจาดีเฉพาะในจอุบลอพยพไปแล้วกว่าครัวเรือ',
#  'เมื่อไหร่ภาครัฐจะออกมาช่วยเหลือพวกเราบ้างหรือนี่ยังลำบากไม่พอที่จะมองเห็นหรอทุกวันนี้มีแต่ประชาชนช่วยเหลือกันเองทั้งนั่น',
#  'เว็บใหม่มาแรงแจกเครดิตฟรีโปรที่ทุกคนรอฝากรับทำถอนได้ทันทีปรับแตกแจกตลอด',
#  'ใครกำลังหางานออนไลน์ทำอยู่มั้ยคะเค้าแนะนำงานนี้เลยเงินดีแถมงานง่ายมีสอนงานฟรีตลอดการทำงานไม่มีค่าสอนสนใ',
#  'ใครที่เห็นทวีตนี้ช่วยกันดันแท็กด้วยนะครับรัฐบาลมันไม่ทำห่าเหวอะไรเลยประชาชนเดือดร้อนกันท่วนหน้ามันมัวแต่มุดหัวอยู่ในหลุ',
#  'ไฟฟ้าใกล้ถูกตัดแล้วนะคะช่วยกันดันแท็กทีค่ะน้ําท่วมอุบล',
#  'ขอออกมาด่ารัฐบาลเลยว่าทำอะไรอยู่ชาวบ้านเดือดร้อนหนักขนาดนี้น้ำท่วมไม่ลดถนนถูกตัดขาดน้ำไฟตอนนี้ไม่ทีใช้และมีเด็กคนแก่รวมถึง',
#  'ขอเป็นส่วนหนึ่งส่งกำลังใจให้ชาวอุบลผ่านพ้นวิกฤตน้ำท่วมไปได้โดยเร็วและช่วยรีข่าวสารเพื่อเป็นกระบอกเสียงและประโยชน์หากใครต้',
#  'งานดีรีวิวแน่นมากใครที่กำลังมองหาค่าขนมช่วงนี้ขอแนะนำงานดีๆสนใจทำงานเสริมเดมมาได้เลยค่ะหมากปริ',
#  'งานดีรีวิวแน่นมากใครที่กำลังมองหาค่าขนมช่วงนี้ขอแนะนำงานดีๆใครที่สนใจทำงานเสริมเดมมาได้เลยค่ะ',
#  'ซยฮขอร่วมเป็นกระบอกเสียงให้กับพี่น้องชาวอุบลและชาวศรีสะเกษที่ประสบอุทกภัยในขณะนี้ฝากรีทวิตแชร์ต่อเพื่อพี่น้อ',
#  'ด่วนเลิกปิดข่าวน้ำท่วมอุบลท่วมหนักจมน้ำทั้งเมืองรุนแรงกว่าปีน้ำขึ้นสูงเรื่อยๆฝนยังคงตกกระหน่ำมองไม่เห็นหลังคาบ้านมวล',
#  'ตอนนี้นะครับผมอยากให้ทุกคนช่วยกันดันแท็กนี้ทีนะครับเพื่อที่หน่วยงานและข่าวต่างๆจะได้สนใจข่าวนี้บ้างถือว่าเป็นการกระจาย',
#  'น้ําท่วมอุบลวิกฤตน้ำท่วมถึงหลังคาไร่นาเสียหายปชชถามรัฐอยู่ไหนเร่งช่วยเหลือ',
#  'รับคนปั่นยอดวิวมีเน็ตว่างงานเดมมาคะเพลงละบาทคลิปละบาทโฆษณาละบาทน้ําท่วมอุบ',
#  'รับคนปั่นยอดวิวมีเน็ตว่างงานเดมมาคะเพลงละบาทคลิปละบาทโฆษณาละบาทแบนมล',
#  'สระบุรีสาหัสตำบลบ้านครัวอบ้านหมอจสระบุรีเมตรครับน้ำท่วมน้ําท่วมนนทบุรีน้ําท่วมอุบล',
#  'หนักจริงๆค่ะมาช่วยกระจายข่าวสารค่ะพี่ๆที่รู้จักบอกว่าบางพื้นที่โดยตัดน้ำตัดไฟและเข้าไม่ได้แล้วน้ําท่วมอุบล',
#  'อุบลศรีษะเกษก็จังหวัดในประเทศไทยนะน้ำท่วมหนักและยาวนานขนาดนี้ภาครัฐไปไหนไหนจะข่าวเอยอะไรเอยทำไมมันเงียบกริบได้ขนา',
#  'เราขอดันแท็กนี้นะคะเพราะเรื่องเงียบจริงๆน้ําท่วมอุบลน้ําท่วมอุบลอุบล',
#  'ใครที่กำลังมองหาค่าขนมช่วงนี้ขอแนะนำงานดีๆแบบนี้น๊าางานดูเพลงได้เงินแน่นอนได้เพลงละบาทเพลง',
#  'ใครที่กำลังมองหารายได้เสริมมาทางนี้โอนจ่ายทุกวันค่ะสนใจคลิกลิงก์หน้าโปรไฟล์ค่ะแบนมิลลิน้ําท่วมนนทบุรีน้ําท่วมอุบ',
#  'ได้ประโยชน์อะไรจากการฟังเพลงชาติในสถานการณ์น้ำท่วมนะ',
#  'กฎกกตวันเหี้ยมากทำให้สสในเขตพื้นที่น้ำท่วมช่วยเหลือชาวบ้านตรงๆไม่ได้ลำบากมากทั้งอุบลศรีสะเกษหน่วยงานรัฐควรเข้',
#  'กระจายช่องทางการช่วยเหลือผู้ประสบภัยน้ำท่วมค่ะช่องทางบริจาคสมทบทุนจุดรับบริจาคสิ่งของลงทะเบียนสำหรับผู้',
#  'ขอบคุณหลายๆเพจที่เข้าช่วยเหลือและขอบคุณหลายคนที่บริจาคให้ผู้ประสบภัยณตอนนี้ท่วมสูงขึ้นเราขอใช้ช่องทางนี้ช่วยเหลือคนในจัง',
#  'คือมันเงียบมากๆมาช่วยกันดันแท็กนะคะตอนนี้น้ำสูงมากๆเลยช่วยๆกันนะคะน้ําท่วมอุบล',
#  'ตอนนี้คนอุบลกำลังเจอวิกฤตน้ำท่วมหนักมากกว่าปีท่วมแบบมิดหลังคาและระดับน้ำยังคงสูงขึ้นเรื่อยๆการเดินทางเข้าเมืองรถเล็กต้อ',
#  'ตอนนี้ที่หลบภัยน้ำท่วมอุบลคือชั้นบนสุดของโรงเรียนแล้ว',
#  'ถึงจะรู้ว่าอุบลน้ำท่วมทุกๆปีแต่ปีนี้น้ำท่วมสูงมากทะลุระดับน้ำของปีเรียบร้อยไม่รู้ต้องใช้เวลานานกี่เดือนน้ำถึงจะลดลงได้แ',
#  'ถ้ายังสนใจกันอยู่ช่วยกันดันแท็กน้ำท่วมหน่อยนะครับตอนนี้คนที่ยังไม่มีผลกระทบอาจจะไม่เป็นอะไรแต่สนใจความเป็นอยู่ของเพื่อนมนุษ',
#  'ถ้าอยากดูว่าสสสจในเขตวารินชำราบทำอะไรบ้างในตอนนี้ถ้าไม่เข้าดูหน้าเพจของสสมาดูที่แอคเราได้นะไม่อยากให้แซะจน',
#  'ทำไมสื่อถึงไม่กับข่าวเรื่องน้ำท่วมวะน้ำท่วมหลายที่เลยนะมัวแต่เล่นข่าวอะไรกันน้ำท่วมอิสานน้ําท่วมอุบล',
#  'ท้องฟ้าเหมือนฝนจะตกอย่าลงมาเพิ่มเลยกันน๊าาาน้ําท่วมอุบล',
#  'ฝากหน่อยคับน้ําท่วมอุบลน้ําท่วมศรีสะเกษ',
#  'รัฐบาลไม่ช่วยแถมกกตยังออกกฎวันห้ามสสมอบสิ่งของช่วยเหลือประชาชนแล้วประชาชนต้องทำไงน้ําท่วมอุบล',
#  'วันนี้เมื่อปีคือวันที่ยิ่งลักษณ์เชิญอภิสิทธิ์มาช่วยหาทางออกเรื่องน้ำท่วมครั้งใหญ่แต่ปีนี้น้ําท่วมอุบลและอีกหลายๆจั',
#  'วิดีโอและรูปภาพนี้ของวันพุธตอนแรกก็คิดว่าคงจะเริ่มระบายออกเรื่อยๆน้ำคงจะลดลงเร็วๆนี้ไปๆมาๆน้ำเริ่มสูงขึ้น',
#  'สภาพร้านตัวเองไม่เหลืออะไรเลยแตกสลายลงไปกับตาน้ําท่วมอุบล',
#  'หางานพาร์ทไทม์ที่ได้เงินจริงนักเรียนนักศึกษาคนว่างงานเค้าแนะนำงานนี้เลยเงินดีแถมงานง่ายไม่กระทบเวลางานและเวลาเรี',
#  'อุบลท่วมทุกปีแต่ต้องยอมรับว่าปีนี้ท่วมหนักน้ำสูงมากและแทบไม่มีข่าวเลยว่าชาวบ้านเดือดร้อนขนาดนี้น้ําท่วมอุบล',
#  'อุบลหนักกว่าที่คิดจมมิดหลังคารัฐจะนิ่งเฉยไม่ได้ละต้องรีบจัดการช่วยเหลือด่วนๆ',
#  'เช้านี้ที่สพขน้ำยังคงเพิ่มขึ้นสำนักงานพัฒนาที่ดินเขตน้ําท่วมนนทบุรีน้ําท่วมอุบล',
#  'เพิ่งผ่านมาวันนี้น้ำคือปริ่มขึ้นมาแล้วรถติดหนักมากเพราะมีแค่เส้นทางเดียวน่ากลัวมากน้ําท่วมอุบล',
#  'แจกเครดิตฟรีไม่ฝากก่อนรีทวิตและกดลิ้งด้านล่างได้เลยแจ้งว่าขอรับเครดิตฟรี',
#  'แท็กที่ต้องดันแสดงให้เห็นเลยว่าร้าบาลบริหารงานล้มเหลวแค่ใหนไม่มีทั้งสมองและศักยภาพยังสาระแนมาบริหารประเทศน้ําท่วมนนทบุรี',
#  'แปลกดีเนอะคนที่เค้าช่วยเหลืออะไรไม่ได้ทำได้เเค่ลงพื้นที่เยี่ยมเยียนเเละให้กำลังใจหรืออะไรที่เค้าพอจะช่วยได้เค้าทำอย่าเต็มคว',
#  'ใครที่ไม่เคยใช้ชีวิตติดแหง็กกับน้ำท่วมทำอะไรไม่ได้นอกจากอยู่ไปวันๆไม่มีทางเข้าใจจริงๆนะแล้วเลิกโทษฝนฟ้าอากาศก่อนก็ในเ',
#  'ก่อนจะแบนมิลลิด่าโตโน่มาช่วยกันบริจาคเยียวยาน้ําท่วมอุบลก่อนได้ไหมจมน้ำมาเป็นเดือนไร้คนเหลียวแลปีนี้ยิ่งสา',
#  'ขอบคุณแอนนาที่เรื่องน้ำท่วมอุบลและศรีสะเกษอยากให้คนคนดังออกมาพูดกันเยอะๆอยากให้สังคมสนใจเยอะๆเผื่อเรื่องมันแม',
#  'ควรให้ความสนใจน้ำท่วมอุบลมากกว่าโตโน่แต่ละช่องมีข่าวน้ำท่วมอุบลน้อยมากทั้งๆที่มันไม่ใช่เรื่องเล็กๆเลยน้ําท่วมอุบล',
ค้ามีงานมาแนะนำทำง่ายค่ะแค่นาทีอยากมีรายได้เสริมต้องเปิดใจ',
#  'ส่วนทางเลือกเดียวสำหรับคนที่ต้องการใช้รถส่วนตัวเพื่อเข้าเมืองก็จะต้องอ้อมไปเส้นกุดลาดบัวท่าบัวเทิงแต่สภาพการจร',
#  'อีกนิดเดียวคือท่วมสะพานพิบูลน้ําท่วมอุบล',
#  'อีกหนึ่งช่องทางการช่วยเหลือค่ะฝากทุกคนรีช่วยกันหน่อยนะคะประสงค์ส่งของเพื่อผู้ประสบภัยน้ำท่วมอุบลราชธานีส่งมาที่ศูนย์',
#  'อุบลฯวารินชำราบอ่วมเพราะต้องรับน้ำที่เร่งปล่อยจากเขื่อนทั้งเขื่อนในลุ่มน้ำมูลและเขื่อนในลุ่มน้ำชีภาพเมื่อวานนี้น้ํา',
#  'เกิดอะไรขึ้นประชาชนช่วยกันเองตลอดภาครัฐช่วยสนใจหน่อยได้มั้ยน้ําท่วมอุบล',
#  'แจกเครดิตฟรีไม่ต้องแชร์กดติดตามกดรีทวิตแคปส่งแอดมินไปรับเครดิตฟรีเครดิตฟรีไม่',
#  'โรงพยาบาลสรรพสิทธิ์ฯนี่เป็นโรงพยาบาลประจำจังหวัดอุบลเลยมั้ยได้ข่าวว่าน้ำถึงโรงพยาบาลแล้วด้วยโรงพยาบาลคือที่ที่มีคนป่วย',
#  'ขอร้องได้โปรดอย่ามาแขวนขายเว็ปขายของโดยหากินกับดังๆอย่ามาหากินบนความทุกข์คนอื่นน้ําท่วมอุบลน้ำท่วมนนทบุ',
#  'ช่วยกันดันเเท๊กหน่อยนะครับคือมันเงียบมากๆอยากน้อยกันทางนี้ก่อนนะครับกระจายๆข่าวให้ทุกคนได้รู้รับทราบด้วยนะครับน้ําท่วมอุ',
#  'ตอนนี้น้ำไหลแรงมากเร่งเก็บเครื่องผลักดันน้ำที่สะพานโขงเจียมเครื่องอโขงเจียมจอุบลราชธานีอุบล',
#  'ติดเทรนได้มั้ยขอร้องตอนนี้น้ำจะถึงรพสรรพสิทธิ์จริงๆแล้วน้ำเก่าไม่ลดน้ำใหม่มาไม่เป็นผลดีมากๆเพราะรพสรรพสิทธิ์เ',
#  'นี่คือภาพที่ทับทิมได้ไปสัมผัสด้วยตัวเองการใช้ชีวิตในภาวะน้ำท่วมสูงไฟฟ้าถูกตัดลำบากมากทั้งเรื่องการหุงหาอาหารการสัญจร',
#  'รักนางน้ําท่วมอุบลวิจารณ์สาวน่าเย็ด',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะแค่นาทีเค้ามีงานมาแนะนำทำง่ายๆค่ะได้เงินจริงทุกแพตฟอมงานไม่มีค่าสมัครไม่ต้อง',
#  'อยากแชร์ข่าวเจ้าหน้าที่แต่ละพื้นที่เข้าช่วยเหลือผู้ประสบภัยอยากแชร์ข่าวผู้ใหญ่ออกมาวางแนวทางแก้ไขอยากแชร์ค่ะใครมีลงเลยนะค',
#  'อยากให้หน่วยงานรัฐเร่งให้ความช่วยเหลือโดยเร็วที่สุดชาวบ้านลำบากเหลือเกินขอเป็นกำลังใจให้ชาวอุบลน้ําท่วมอุบลในภาพคือ',
#  'อย่าพึ่งให้แท็กจมคือมันมีหลายครัวเรือนเดือดร้อนอยากให้รัฐเร่งหาทางช่วยเหลือเลิกสร้างภาพเอาหน้าสักทีแก้ปัญหาให้ตรงจุดห',
#  'อีสานน้ำท่วมมาพักใหญ่ละแต่อีพวกรัฐบาลสัสนรกไม่เคยดูดำดูดีเลือกตั้งรอบหน้าก็จำกันไว้นะคะอย่าให้มันมาหลอกว่ารักคนอีสาน',
#  'เมตตาผลไม้น้องแตงโมด้วยนะคะทุกคะแนนเข้าวัดหมดเลยจ้าทอดกฐินบ้านศาลาบชไทยพาณิชรสิตาผางามน้ําท่วม',
#  'เรื่องที่ถูกมองข้ามไปอีกหนึ่งเรื่องคือน้ำท่วมที่หมู่บ้านเคหะฯข้างแม็กโคศรีสะเกษทางเข้าออกหมู่บ้านน้ำท่วมสูงมากน้ําท่วมศ',
#  'เห็นข่าวนี้แล้วค่อนข้างโกรธนะโกรธที่เราทำอะไรไม่ได้เพราะไม่มีกำลังทรัพย์เพียงพอแต่คนที่มันทำได้กลับนิ่งเฉยโดยเฉพาะภาค',
#  'แจกตลอดทักหาแอดมินได้เลยยยเครดิตฟรีกดติดตามกดรีทวิตกดหัวใจแคปรูปส่งให้แอดมินแจกจริงทักตรงนี้',
#  'กกตยกเลิกวันของสสภาคอีสานได้มั้ยชาวบ้านเดือดร้อนขนาดนี้หรือใช้กรณีภาวะเร่งด่วนก็ได้ให้เขาได้ช่วยเหลือประชาชนในพื้น',
#  'ขอประชาสัมพันธ์นะคะสามารถร่วมสนับสนุนบริจาคได้ที่โกดังมิวสิคสเตชั่นโกดังมิวสิคสเตชั่น',
#  'ขอฝากน้ําท่วมศรีสะเกษด้วยนะคะทางศรีสะเกษเองก็ท่วมหนักเหมือนกันค่ะตามแต่ละอำเภอในตัวเมืองหรือแม้แต่ในสถานศึกษาลำบาก',
#  'จากในแผนที่นี้จะเห็นว่ามีโรงพยาบาลวารินชำราบซึ่งใช่ค่ะน้ำได้เข้าไปประชิดโรงพยาบาลแล้วสถานการณ์น้ําท่วมอุบลในตอน',
#  'ดวงแม่นๆประจำสัปดาห์นี้โดยหมอไก่พพาทินีมาแล้วจ้าสัปดาห์นี้คนเกิดวันเสาร์มงลงความสำเร็จสมหวังมารออยู่หน้าบ้านแ',
#  'ด่วนช้าหมดอดนะจ๊ะรีทวิตหัวใจคอมเมนแจกจริงแคปส่งงานให้แอดมินที่นี่เครดิต',
#  'ตอนกทมลาดกะบังทองหล่อน้ำท่วมสูงน้ำขังนานสมัยชชเงียบกริ๊บบจนนึกว่าเคี้ยวอะไรเหนียวๆอุดปากอยู่',
#  'ตอนนี้มีช่องทางช่วยเหลือเบื้องต้นตามข้อมูลในภาพสามารถเข้าไปบริจาคสิ่งของหรือยอดเงินเพื่อช่วยเหลือผู้ประสบภัยกันได้ค่ะ',
#  'ติดเทรนได้แล้วน้าน้ำเข้ามากลางเมืองแล้วมีรพสรรพสิทธิ์รพใหญ่สำคัญมีผู้ป่วยมารักษาเยอะมีวิยาลัยพยาบาลสนามบินที่น่าเป็นห่',
#  'ต่อให้แท็กแมสถ้าเขาบ่สนใจมันก็เท่านั้นทั้งรัฐทั้งสื่อมุ่งแต่เรื่องที่เป็นกระแสติดลมบนน้ําท่วมอุบลน้ําท่วมศรีสะเกษน้ำท่',
#  'ทางเข้าออกหมู่บ้านโดนตัดขาดทางเดียวที่เข้าได้ตอนนี้คือทางเรือบ้านหนองบัวไซยวานอำเภอกันทรมรมย์มีระดับน้ำที่สูงและไหลแร',
#  'ทำเวลาไหนก็ได้มีแค่เน็ตมือถือก็ทำได้แค่ขยันก็ได้เงินทุกวันเป็นงานเพิ่มยอดขายให้กับร้านค้าแบนมิลลิมิ',
#  'นาทีน้ำทะลักเข้าห้างหลังกำแพงกั้นน้ำแตกน้ําท่วมอุบล',
#  'นายกอยู่ไหนผู้ว่าอยู่ไหนประชาชนเดือดร้อนน้ําท่วมน้ําท่วมอุบลน้ําท่วมอีสาน',
#  'น่ากลัวมากอหน้ำท่วมจะมิดหลังคาแล้วแต่ข่าวเงียบมากเอาจริงถ้าไม่เห็นผ่านๆในทวิตกุก็ไม่รู้อะรัฐหรือสื่อข่าวช่วยให้ความสนใจกั',
#  'น้ำท่วมจนคนเสียชีวิตแล้วจะแก้ไขปัญหายังไงน้ําท่วมอุบล',
#  'น้ําท่วมอุบลในฐานะคนพื้นที่ทุกวันนี้อุบลจะกลายเป็นเมืองบาดาลแล้วคับ',
#  'บังคับรีค่ะน้ำท่วมหนักค่ะตอนนี้ลองดูทางเพจได้เลยนะคะอุบลวันนี้อุบลเคเบิลทีวีลองๆเลื่อยดูกันได้เลยนะคะล่า',
#  'ฝากรีค่ะน้ําท่วมอุบล',
#  'มันน่าหดหู่จริงๆๆน้ำท่วมหนักมากชาวบ้านจะอยู่กันยังไงบรรดาน้องสัตว์เลี้ยงอีกทีหนักกว่านั้นคือการช่วยเหลือจากหน่วยงานต่',
#  'มีศูนย์ช่วยเหลือผู้ประสบภัยที่ไหนบ้างมาแชร์กันนะคะความช่วยเหลือจะได้ไปถึงไวๆน้ําท่วมนนทบุรีน้ําท่วมอุบลน้ําท่วมกรุงเท',
#  'รายงานสถานการณ์เส้นทางเดินรถวันที่ตุลาคมขอให้ประชาชนผู้ที่ใช้รถใช้ถนนเดินทางอย่างอย่างระมัดระวังเพื่อความปลอ',
#  'ลูกชายน่ารักขอบคุณคับลูกที่ช่วยแชร์น้ําท่วมอุบลน้ําท่วมอุบลน้ําท่วมอีสานเป็นจังหวัดที่พี่เ',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะแค่นาทีเค้ามีงานมาแนะนำทำง่ายๆค่ะได้เงินจริงทุกแพตฟอมงานไม่มีค่าสมัครไม่ต้องหา',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมค่ะรีวิวแน่นมากค่าเค้ามีงานมาแนะนำทำง่ายค่ะแค่นาทีอยากมีรายได้เสริมต้องเ',
#  'เมื่อกี้ขับรถมาดูน้ำในเมืองเส้นหน้ารพกับเส้นพิชิตรังสรรค์หน้ารพถึงประมาณร้านพิซซ่าขออย่าให้ขึ้นไปมากกว่านี้เลยน้ําท่ว',
#  'เส้นนี้ปกติเป็นเส้นหลักที่ชาวบ้านใช้สัญจรวารินฝั่งเมืองปกติเดินทางประมาณนาทีตอนนี้คือเข้าเมืองทีต้องใช้ทางอ้อ',
#  'เอาอะไรมาไหวท่วมขนาดนี้ยังไม่แมสอีกเหรอน้ําท่วมอุบล',
#  'แล้วคนแก่ที่เค้าอยู่บ้านคนเดียวอ่ะเค้าจะช่วยเหลือตัวเองได้มั้ยจังหวะที่ชุลมุนอ่ะคงไม่มีใครทันสังเกตุแค่คิดก็เครียดแล้ว',
#  'ใครที่อยากช่วยเหลือและบริจาคสิ่งของสามารถดูรายละเอียดได้จากโพสต์นี้เลยนะคะน้ำท่วมอุบลน้ําท่วม',
#  'คุณช่วยดันสระบุรีด่วนด้วยช่วยกันน้ำป่าทะลักชาวบ้านไม่ทันตอนนี้ก็ขาดแคลนเพราะตั้งตัวไม่ทันเห้อทำไมมันไม่เตือนห',
#  'จะบริจาคช่วยเหลือผ่านบัญชีอยากให้โดเนทผ่านชื่อบัญชีที่ตั้งขึ้นเฉพาะเกี่ยวกับผู้ประสบภัยหรือหน่วยงานของมหาลัยจะดีกว่านะ',
#  'จะมีจุดศูนย์ช่วยเหลือจากกทมเมื่อไหร่ว้าาาาาน้ําท่วมอุบล',
#  'ช่วงนี้ขอรีน้ําท่วมอุบลนะคะข่าวเงียบจริง',
#  'ด่วนพื้นที่อบตโรงช้างถนนกั้นคลองชลประทานแตกน้ำไหลจากที่ตัวอป่าโมกโรงช้างไปที่บางปะหันอยุธยารับน้ำต่อ',
#  'ถ้าไม่มีแท็กนี้คงไม่รู้ว่าอุบลน้ำยังท่วมอยู่ไม่มีข่าวไม่มีประกาศอะไรจากทางรัฐขอให้ทุกคนช่วยกันดันแท็กด้วยค่ะเห็นใจทุกคน',
#  'ทั้งนํ้าท่วมทั้งลมหนาวลมทั้งวันจริงๆน้ําท่วมอุบล',
#  'นี่ทราบข้อมูลข่าวสารน้ำท่วมจากทวิตล้วนๆว่าสถานการณ์เป็นไงบ้างสื่อข่าวแทบจะให้ข้อมูลน้อยมากไม่รู้ว่าทำอะไรกันอยู่ดูแล้วก็สง',
#  'น้ำต้องมาอีกแน่ๆมันหนักเกินข่าวมันก็ไม่ค่อยมีเลยสื่อหลักๆก็มีแต่ไปสนใจนักว่ายน้ำมากเกินไปส่วนรัฐบาลก็นั่นะละนะ',
#  'น้ำเข้าตัวเมืองแล้วนะคะอีกวันน้ำน่าจะถึงหน้ารพสรรพสิทธิ์เมื่อวานทางรพได้นำกระสอบทรายมาทำกำแพงกั้นน้ำแล้วค่ะน้ํ',
#  'น้ําท่วมราษีไศลน้ําท่วมศรีสะเกษน้ําท่วมอุบลล้วนเกี่ยวเนื่องกันเพราะน้ำจากราษีไศลจากศรีสะเกษจะไหลไลงแม่น้ำมูลที่อุบล',
#  'น้ําท่วมอุบลพื้นที่น้ำท่วมใหม่เกิดขึ้นทุกวันระดับน้ำมเวลานนับว่าน้ำท่วมสูงสุดในรอบ',
#  'น้ําท่วมอุบลเส้นทางเดินรถเส้นทางเดียวที่จะเข้าเมืองอุบลฯตอนนี้รถติดมากหลังน้ำท่วมถนนหลายเส้นทางจนรถขนาดเล็กหรือกร',
#  'เพราะสลิ่มมัวแต่ด่าชัชชาติว่าน้ำท่วมกทมแต่ไม่เคยโผล่หัวออกมาดูว่าน้ำท่วมอุบลน้ำท่วมอยุธยาน้ำท่วมนครสวรรค์หนักขนาดไหนแ',
#  'เราขออนุญาตทุกคนช่วยให้ความสนใจเเละเเพร่กระจายข่าวนี้ไปหน่อยค่ะรู้สึกว่ามันเงียบมากตอนนี้ทั้งเด็กผู้สูงอายุชาวอุบลกำ',
#  'เลิกขายของเลิกลงเว็บพนันคนจะตามข่าวไอสัสแหกตาดูสถานการณ์บ้านเมืองบ้างนะอิเหี้ยน้ําท่วมอุบล',
#  'เลิกบอกว่ามันเป็นธรรมชาติเลิกบอกว่ามันคือที่รับน้ำเลิกเคยชินกับภัยพิบัตินี้เลิกสมองกลวงแล้วคิดแก้ปัญหาค่ะน้ําท่วมอุบล',
#  'เส้นทางเข้าเมืองตอนนี้คือเกือบโดนตัดขาดแล้วอะทางกลับบ้านก็โดนน้ำท่วมหมดเลยน้ําท่วมอุบล',
#  'แจกเครดิตฟรีไม่ต้องฝากก่อนได้รับยูสเก่าและใหม่รีทวิตกดลิ้งไปขอรับฟรี',
#  'โวยรถลากข้ามถนนจุดน้ำท่วมริมอ่างเก็บน้ำเรียกเก็บเงินค่าจ้างผู้ให้บริการโต้ต้องซื้อน้ำมันมาเติมเองไม่ได้รับการสนับสนุ',
#  'ใครที่กำลังมองหางานรายได้เสริมก็ขอเชิญทางนี้งานง่ายมากไม่ยากเลยรายได้วันสมัครฟรีสอนฟรีได้เงิน',
#  'ใครที่กำลังมองหารายได้เสริมมาทางนี้โอนจ่ายทุกวันค่ะสนใจคลิกลิงก์หน้าโปรไฟล์ค่ะแบนมิลลิน้ําท่วมนนทบุรี',
#  'ใครสนใจหาค่าขนมมาทางนี้เลยค่ะไม่ใช่การพนันงานถูกกฎหมายสนใจกดลิงค์หน้าโปรไฟล์มาสอบถามก่อนได้คะหมากปริญพรหมลิขิต',
#  'ใช่ค่ะภาพนี้เป็นภาพของอำเภอที่ดิฉันอาศัยอยู่ถึงจะคนละตำบลตำบลดิฉันน้ำไม่ท่วมนะคะตอนนี้อยากจะบอกว่าไม่มีสัญญาณอะไรจากรั',
#  'ไม่ค่อยเป็นข่าวเลยน้ำท่วมอุบลหนักในรอบปีฝากกระจายข่าวด้วยครับส่งกำลังใจและขอให้ทุกคนปลอดภัยผ่านช่วงเวลานี้ไปให้ได้น',
#  'ไม่ปิดรรว่ะน้ําท่วมอุบล',
#  'ขอโทษนะสื่อต่างๆเงียบจังแทบไม่ได้ยินข่าวน้ำท่วมเลยอะบางสื่อก็ออกนะแต่ไม่ขยี้ให้สุดหน่วยงานภาครัฐทำอะไรอยู่เห็นแต่ชาว',
#  'ข่าวทีวีเค้าเป็นอะไรกันไม่มีใครไปทำข่าวที่อุบลเหรองงมากออกแต่ข่าวฆ่ากันตายตอนนี้คนอุบลเค้าก็จะตายกันแล้วน้ําท่',
#  'คนนี้เค้าตอบคำถามด้วยสมองตัวเองหรือมีคนเขียนมาให้เค้าตอบนะ',
#  'จะบริจาคของน้ำท่วมบริจาคเงินและสิ่งของอุปโภคบริโภคทางไหนได้บ้างค่ะใครรู้ส่งรายละเอียดเม้นไว้ให้หน่อยค่ะเราจะบริจาคเงินแ',
#  'จำเอาไว้เด้อพี่น้องอีสานเอ้ยยมันผู้ใดเว้าอิหยั่งไว้แต่เฮ็ดบ้อได้ก้ออย่าไปเลือกมันมาเป็นผู้แทนพวกสูเจ้าเด้อ',
#  'จุกนะคำว่าเครียดเนี่ยน้ําท่วมอุบล',
#  'ชาวบ้านประชาชนต้องออกมาช่วยเหลือกันเองถามจริงมีรัฐบาลไว้เพื่ออะไรยังจำเป็นอยู่ไหมถ้าข่าวไม่ดังก็จะไม่มาเอาหน้าว่า',
#  'ช่วยๆกันนะยามคับขันน้ําท่วมอุบล',
#  'ดูข่าวทางทีวีวันนี้มีแค่นักข่าวลงไปทำข่าวกับของช่วยเหลือที่รับบริจาคมาจากประชาชนอีกทีน้ำท่วมมานานมากเราตามจากแท็กแต่ทำไมไม่มี',
#  'ตั้งแต่เราเกิดมาเราก็ไม่เคยเห็นบ้านย่าที่สุรินทร์น้ำท่วมขนาดนี้อ่ะคือมันไล่มาจากอุบลศรีสะเกษบุรีรัมย์สุรินทร์น้ำเยอะมาก',
#  'ตึกสูงๆทางขวานั่นโรงพยาบาลสรรพสิทธิ์ประสงค์โรงพยาบาลประจำจังหวัดโรงพยาบาลศูนย์รถพยาบาลรับส่งผู้ป่วยเริ่มมีปัญหาเลี่ยงน้ำ',
#  'ต้องรอให้ท่วมถึงขนาดไหนถึงจะเป็นข่าวดังถึงจะได้รับการช่วยเหลือประชาชนลำบากเมื่อไหร่จะได้รับการแก้ไขปัญหาสักทีน้ํา',
#  'ถ้ารัฐบาลฯทำงานเป็นพรุ่งนี้ตั้งศูนย์ช่วยเหลือฉุกเฉินได้เลยน้ําท่วมอุบลคงต้องรอรัฐบาลหน้ารัฐบาลนี้เงินช่วยเหลือรอบที่แล้ว',
#  'ทางเข้าวารินอุบลทางสุดท้ายเริ่มจะไม่รอดแล้วค่ะน้ําท่วมอุบล',
#  'ทำไมข่าวน้ำท่วมอุบลเงียบมากช่วนกันดันๆน้ําท่วมอุบล',
#  'ที่อุบลแย่มากๆอะละเค้าอยู่แบบนี้มาเป็นเดือนๆแล้วรัฐบาลมีไว้ทำไมอะถ้าแก้ปัญหาไม่ได้น้ําท่วมอุบล',
#  'นอกจากน้ําท่วมอุบลฝากน้ําท่วมศรีสะเกษด้วยนะคะปีนี้หนักมากจริงๆหลายอำเภอแทบจะเป็นเกาะแล้วถนนหลักก็ถูกปิดหลายเส้นทางมาก',
#  'นาทีนี้ต้องฝากรับเลยทำเทิร์นถอนไม่อั้นสนใจสมัครแคปภาพแจ้งแอดมินได้เลยจ',
#  'นี่คือบ้านของเราเองน้ำท่วมบ้านมาสัปดาห์แล้วท่ามกลางเรื่องร้ายๆยังมีเรื่องดีๆอยู่รับปริญญาของฉันทำให้ครอบครัวมีรอยยิ้ม',
#  'น้ำท่วมขนาดนี้นักข่าวเฉยรัฐบาลประเทศเฉยประเทศเหี้ยไรเนี่ยน้ําท่วมอุบล',
',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะเค้ามีงานมาแนะนำทำง่ายค่ะแค่นาทีสนใจคลิกลิ้งก์หน้าโปรไฟล์มาค่ะแบนมิลลิน้ําท่วม',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมคะแค่นาทีเค้ามีงานมาแนะนำทำง่ายๆค่ะงานไม่มีค่าสมัครไม่ผิดกฏหมายไม่ใ',
#  'สวัสดีค่ะมีใครว่างหาค่าขนมอยู่ไหมค่ะรีวิวแน่นมากค่าเค้ามีงานมาแนะนำทำง่ายค่ะแค่นาทีอยากมีรายได้เสริมต้องเปิดใจพร',
#  'สวัสดีค่ะใครว่างหาค่าขนมอยู่ไหมคะเค้ามีงานมาแนะนำทำง่ายๆค่ะได้เงินจริงทกแพตฟอร์มงานไม่มีค่าสมัครไม่ต้อ',
#  'สวัสดีค่ะใครว่างหาค่าขนมอยู่ไหมคะเค้ามีงานมาแนะนำทำง่ายๆค่ะได้เงินจริงทกแพตฟอร์มงานไม่มีค่าสมัครไม่ต้องหาลูกทีม',
#  'สสพปชรจอุบลมีไหมชื่ออะไรน้ําท่วมอุบล',
#  'สาธุอนุโมทนาด้วยขอให้ความยุติธรรมจงบังเกิดแตงโมต้องได้รับความยุติธรรมอัจฉริยะหมอธวัชชัย',
#  'สิ่งที่ประเทศไทยสูญเสียอยู่ตอนนี้ผู้นำที่ดีการบริหารจัดการที่ดีการวางแผนป้องกันและแก้ไขที่ดีความยุติธรรมที่มี',
#  'สิ่งที่รัฐทำไม่ได้แต่เว็บพนันกับแก๊งค์คอลเซ็นเตอร์ทำได้น้ําท่วมอุบล',
#  'สี่แยกกรุงไทยบ้านดู่น้ำดันมาเรื่อยๆจนชาวบ้านต้องใช้เรือแล้วอะน้ําท่วมอุบลน้ําท่วม',
#  'สื่อควรออกจากพื้นที่กราดยิงหนองบัวลําภูแล้วมูฟออนไปให้ความสำคัญกับน้ําท่วมอุบลน้ำท่วมได้แล้วเพราะยิ่งอยู่ยิ่งต',
#  'สื่อส่วนใหญ่ตอนนี้ยังไม่มุ้บจากข่าวกราดยิงยังอัพเดตข่าวกราดยิงอยู่ตลอดส่วนตัวเรามองว่าคนตายตายไปแล้วเราทำอะไรไม่ได้แล้วต',
#  'สื่อหลักหลายช่องรายงานข่าวน้ำท่วมอุบลมานานแล้วหลายช่องนั่งเรือไปกับกู้ภัยตากแดดตากฝนในเรือหลายชมเพื่อนำภาพผู้ประสบภัยที่เดื',
#  'สูมันหนักมากเลยนะนิ่น้ําท่วมอุบลน้ําท่วมอุบลน้ําท่วมอิสาน',
#  'สู้ๆนะคะเป็นกำลังใจค่ะขอให้สำเร็จนะคะโตโน่น้ําท่วมอุบล',
#  'หนักกว่าแล้วอิควายรัฐบาลมึงทำไรอยู่น้ําท่วมอุบล',
#  'หนักขนาดไหนขนาดที่ว่าเมื่อวานยังใช่รถล้อใหญ่ได้แต่วันนี้ใช้ไม่ได้แล้วเนื่องจากมองไม่เห็นพื้นถนนน้ําท่วมศรีสะเก',
#  'อุบลปีก่อนก็ท่วมหนักปะที่พี่บิณฑ์ไปนั่งนับโทรศัพท์กับรบอะน้ําท่วมอุบล',
#  'อุบลอ่วมแน่น้ําท่วมอุบล',
#  'ฮรืออออออเดือดร้อนทั้งคนในพื้นที่และคนที่จะเดินทางเลยอ่ะนี่จะกลับบ้านในรอบครึ่งปีแต่เส้นทางที่จะกลับน้ำท่วมทั้งนั้นจะได้กลั',
#  'เครดิตฟรีบาทกดติดตามหัวใจรีทวิตถอนได้เลยมีโปรหนักๆรับพร้อมโปรทุนน้อยทำกำไรต่อวันรับที่',
#  'เครดิตฟรีล่าสุดขั้นตอนการรับง่ายๆแค่นี้รีทวิตกดหัวใจแคปโพสให้แอดมินส่งข้อมูล',
#  'เจ้าสัวคนร่ำรวยหลายๆท่านน้ำอาหารสำคัญค่ะเวลานี้ถึงเวลาที่ท่านต้องออกตัวมาช่วยแล้วค่ะน้ําท่วมอุบลน้ําท่วมศรีสะเกษ',
#  'เปิดเพลงชาติคือเตรียมความพร้อมอิหยังวะโอ้ยน้อออออยากหยุมหัวคนเด้',
#  'เป็นกำลังใจให้นะคะน้ำทะเลมาหนุนสูงอีกเปิดตัวได้แล้วผู้จัดไม่ควรเอาเปรียบติ่งมิลลิน้ําท่วมอุบลน้ําท่วมกรุ',
#  'เผื่อลืมเคยมีผู้บริสุทธิ์ตายจากคำว่าสิทธิมนุษยชนนะเจ้าคะก็ไม่ได้เชียร์ให้รัสเซียทำลายยูเครนนะเจ้าคะแค่เราต่อต้าน',
#  'เมืองศรีสะเกษกำลังจมน้ำบางพื้นที่ก็จมมิดหลังคาไปแล้วพวกเราต้องการคำตอบว่าปีนี้เป็นเหี้ยไรเห็นโทษแต่พายุโนรูมึงนี้',
#  'เมื่อวิกฤตคาร์บอนสะเทือนไปทั้งโลกพลังงานทางเลือกคือความหวังสุดท้ายเปิดนวัตกรรมพลังงานทางเลือกใหม่มุ่งสู่',
#  'เยอะแล้วเนี้ยยยเรทซื้อทีสิบยี่สิบแต่ก็เงินนะแบนมิลลิอย่าลืมช่วยน้ําท่วมอุบล',
#  'เรารบกวนเพื่อนๆทุกคนที่เห็นทวิตนี้ไปช่วยกันดันแท็กน้ําท่วมอุบลน้ําท่วมอีสานทีนะคะตอนนี้ข่าวเงียบมากๆเลย',
#  'เราอยู่คนละฝั่งค่ะเลยพอไปส่งของให้ลูกค้าได้แต่นี่ท่วมหนักเลยข่าวก็เงียบไม่ติดเทรนด์เลย',
#  'เริ่มจากเปิดคอมเม้นเพจก่อนเลยประชาชนจะได้ร้องถูกที่น้ําท่วมอุบลน้ําท่วมศรีสะเกษ',
#  'เลิกสนใจข่าวโตโน่มาสนใจอุบลที่กำลังท่วมทั้งจังหวัดแล้วรัฐบาลหาแต่เงินไม่สนใจชาวบ้านก่อนมั้ยน้ำท่วมจนจะโดนตัดน้ำตัดไฟแ',
#  'เส้นที่รถทหารวิ่งพาคนข้ามอุบลวารินก็คือขนาดนี้แล้วนะรถกระบะยกสูงยังแทบมิดคือแบบผู้วงผู้ว่าภาครัฐต่างๆทำอะไรกันอยู่อ่าอยาก',
#  'เหนื่อยมากวันนี้กว่าจะจัดร้านเสร็จใครสนใจหาเงินเข้ากระเป๋าติดต่อมาได้เลยนะคะไม่ใช่การพนันได้เงินจริงสามารถ',
#  'เห็นด้วยนะโดยเฉพาะกองทุนเครดิตประชาชนแก้หนี้นอกระบบบำนาญประชาชนเดือนละบาทกระตุ้นเศรษฐกิจอีกอันที่ชอบคือเรียนฟ',
#  'เห็นในกลุ่มคนนนทบุรีเขาประกาศรับบริจาคเลือดให้คุณแม่เขานะคะรายละเอียดดังภาพเลยบริจาคเลือดสภากาชาดไทยน้ำท่วมน้ําท่ว',
#  'เอาจริงคนรอบตัวบางคนยังนึกว่าเป็นน้ำท่วมธรรมดาอยู่เลยแต่เอาจริงไม่ธรรมดาละนะน้ำถึงหลังคาคือไม่ธรรมดาละสูน้ําท่วมอุบล',
#  'เอ้า',
#  'แกคิดว่าความเสียหายจากน้ำท่วมครั้งนี้มันเท่าไหร่หรอคะตัวเลขคร่าวๆคือห้าพันล้านบาทนะคะสเกลมันใหญ่เกินกว่าที่จะมีแค่รถทหารมัน',
#  'แกน้ำมันสูงมากจริงๆเข้าแท็กดูแล้วยังตกใจเมืองเหมือนจมอยู่ในน้ำชาวบ้านเค้าอาศัยอยู่กันยังไงก่อนรัฐบาลมีมาตรการอะไรหรือยัง',
#  'แจกฟรีทำยอดถอนได้ทำยอดถอนได้สมัครกดกดติดตามกดรีทวิตก',
#  'แจกเครดิตฟรีไม่ต้องแชร์กดติดตามกดรีทวิตแคปส่งแอดมินไปรับเครดิตฟรีเครดิตฟรีไ',
#  'แท็กติดเทรนได้ยังคือมันไม่ใช่เรื่องเล็กๆเลยนะน้ําท่วมอุบล',
#  'แม่บอกเป็นบุญตามากเลยที่มีโอกาสได้เห็นน้ำท่วมกูผู้ได้แต่เอ๊ะในใจน้ําท่วมอุบล',
#  'แล้วตัวสสทำได้แค่นั้นมอบสิ่งของช่วยเหลืออะไรไม่ได้แล้วทีนี้ถ้าสสคนไหนมอบนู้นนี่ช่วยเหลือมันก็จะเอามาเล่นงานแน่ๆร้ายมากนะ',
#  'แล้วเสร่อไปว่ายน้ำข้ามแม่น้ำโขงอีดอกแหกตาดูบ้างน้ําท่วมอุบล',
#  'แหกตาดูหน่อยคนที่เค้าเดือดร้อนอยู่ตรงนี้อ่ะทำงานให้มันเร็วกับการที่เป็นผู้นำหน่อยดิว๊ะชาวบ้านแทบจะกินจะนอนไม่ได้กันแล้วโกร',
#  'แหกตาดูแล้วลงมาช่วยเหลือประชาชนกฎเหล็กบ้าบ้อนั่นก็ไม่ควรพิจารณาได้แล้วนะไม่ใช่ปล่อยให้ประชาชนอยู่อย่างลำบากมีอำนาจแต่ไม่คิดจะ',
#  'แหล่งรวมความสนุกเพียงแค่คลิกเดียว',
#  'โชคดีที่กลุ่มฝนชุดใหญ่กลุ่มนี้มันสู้ลมหนาวไม่ได้โดนพัดลงไปด้านล่างตอนนี้อุบลหนาวแล้วน้ําท่วมอุบล',
#  'โมโหชิบหายเพราะเรามันต่างจังหวัดเหรอถึงไม่ได้รับความสนใจถ้าอย่างงั้นกุก็ขอให้กรุงเทพน้ำท่วมแบบนี้เป็นเดือนๆแล้วไม่ได้รับ',
#  'โลกแตกเหอะอิดอกในบ้านน้ำก็ท่วมยาบ้าก็เกลื่อนเต็มถนนมีคนบ้ากราดยิงเด็กกับนายกควายๆรัฐบาลห่วยๆนอกบ้านก็จะมีสงคราม',
#  'โหเคาะเรียกรัฐบาลหน่อยยังไม่ตื่นป่าวชาวบ้านลำบากมากน้ําท่วมอุบลน้ําท่วมอุบลน้ําท่วมอุบล',
#  'โอยไอพวกรัฐทำไรกันอยุ่น้ําท่วมอุบล',
#  'โอ้ยยยบ้านเมืองเรามาถึงจุดนี้แล้วทุกคนก็ทุกข์กันพอแล้วน้ําท่วมอุบล',
#  'โอ้โหทำไมแท็กไม่ขึ้นเทรนทำไมดูไม่เป็นเรื่องใหญ่คนเขาเดือดร้อนกันขนาดนี้ทำอะไรกันอยู่น้ําท่วมอุบล',
#  'ใครที่กำลังมองหารายได้เสริมมาทางนี้โอนจ่ายทุกวันค่ะสนใจคลิกลิงก์หน้าโปรไฟล์ค่ะแบนแบนมิลลิหม้อไฟแห่',
#  'ใครที่กำลังมองหารายได้เสริมมาทางนี้โอนจ่ายทุกวันค่ะไม่เสียค่าสมัครไม่ใช่การพนันสนใจคลิกลิงค์ที่หน้าโปร์ไฟ',
#  'ใครที่กำลังมองหารายได้เสริมมาทางนี้โอนจ่ายทุกวันค่ะไม่เสียค่าสมัครไม่ใช่การพนันสนใจคลิกลิงค์ที่หน้าโปร์ไฟล์',
#  'ใครที่มีทุนทรัพย์ที่สามารถจะบริจาคได้ก็ช่วยเหลือกันนะครับถ้าหากท่านใดไม่มีเราก็ใช้สื่อใช้พื้นที่ทางโซเชียลช่วยกันกระจาย',
#  'ใครที่ยังไม่ได้นอนสามารถมาช่วยกันดันแท็กน้ําท่วมอุบลน้ําท่วมอุบลเพื่อช่วยชาวอุบลกันได้นะคะตอนนี้น้ำท่วม',
#  'ใครที่อยากร่วมบริจาคอาหารสุนัขสามารถไปบริจาคได้ที่ร้านลองเดอนัวหน้าฉัตรสุรีย์แมนชั่นสอบถามระเอียดได้',
#  'ใครอยากมีอยากได้อยากมีเงินเหลือใช้คลิ้กลิ้งหน้าโปรไฟล์ได้เลยนะคะไม่ใช่พนันไม่มีค่าสอนโป๊ปเบลล่าพรหมลิขิตคมิ้ง',
#  'ในขณะที่เรากำลังใช้ชีวิตปกติแต่ยังมีเพื่อนร่วมประเทศต้องเจอปัญหาน้ำท่วมข่าวเงียบมากจังน้ำท่วมราษีไศลน้ําท่วมศรีสะเกษ',
#  'ให้ชายแก่ๆสันดานขี้โกงเดินก็แทบจะไม่ไหวต้องมีคนช่วยพยุงมานั่งตำแหน่งประธานกนชมันก็มีแต่จะบรรลัยฉิบหายกันหมดเท่า',
#  'ไม่ต้องฝากชื่อต่อสิทธิ์เท่านั้นกดติดตามทวีตหัวใจสมัครฟรีเพิ่มบัญชีแล้วไปรับสิทธิ์',
#  'ไม่มีอะไรจะน่าพิศวงไปกว่าการที่น้ำท่วมหลายจังหวัดในประเทศแต่รัฐบาลเงียบเหมือนตายห่ากันหมดงงน้ําท่วมนนทบุรีน้ําท่วมศรีสะ',
#  'ไม่รู้จะเริ่มด่าตรงไหนก่อนเลยถ้ามันวิกฤติแล้วจะต้องเตือนทุกห้านาทีก็ต้องทำมั้ยมีหอเตือนภัยแต่ใช้การแจ้งทางอื่นแ',
#  'ไม่ใช่คำว่าสงสารแต่เป็นเห็นใจชาวอุบลมากๆเข้าใจท่วมเกือบทุกปีแต่ปีนี้มันหนักมากจริงแล้วข่าวก็เงียบมากทุกอย่างเคลื่อนไหวโดยป',
#  'ไม่ใช่ว่าเราไม่เสียใจกับเหตุกรารณ์ที่เกิดขึ้นที่ผ่านมาแต่ว่าคนที่ยังมีชีวิตอยู่ก็ต้องเดินหน้าสู้ต่อไปหรือเปล่าเราไม่ได้ต้อ',
#  'ไม่ได้อ่อยแต่อร่อยมากๆนะแคปชั่นอ่อยแคปชั่นสวยน้ําท่วมอุบล',
#  'ไอ้ตู่ไม่คิดแก้ปัญหาน้ำท่วมน้ำแล้งเผลอๆมันจะเป็นายกอีกในสมัยเลือกตั้งหน้าปชชอ่วมน้ําท่วมนนทบุรีน้ําท่วมอุบล',
#  'กตตคุณช่วยชาวอุบลได้นะแค่เปลี่ยนกฎในภาวะเร่งด่วนให้สสในพื้นที่ให้เค้าได้ช่วยชาวบ้านน้ําท่วมอุบล',
#  'กลุ่มฝนที่กำลังเคลื่อนตัวมาทางอุบลน้ําท่วมอุบล',
#  'กว่าจะเลื่อนเจอสาระข่าวสารในแท็กแม่งมีแต่แอคเหี้ยไรเต็มไปหมดบล็อคเท่าไหร่ก็ไม่หมดด้วยนะน้ําท่วมนนทบุรีน้ําท่วมอุบล',
#  'กว่าจะได้ขึ้นรถมาทำงานกว่าจะได้ขึ้นรถกลับบ้านสู้มากบอกเลยน้ําท่วมอุบล',
#  'กะมาเล่นแปปเดียวสงสัยได้ปั่นกันยาวๆสล็อตบาคาร่าแทงบอลแจกเครดิตโปรโมชั่นสล็อต',
#  'กะเอาอุบลเป็นเมืองบาดาลจริงๆนะเว้ยถ้ามันขนาดนี้อะน้ำท่วมทุบสถิติปีไม่เกินจริงตอนนี้ศรีสะเกษก็ท่วมหนักเช่นกันอยากจะกรี๊ดเพร',
#  'การเปิดเพลงชาติเป็นการเตรียมความพร้อม',
#  'กำลังใจครับ',
#  'กุสลดใจมากสถานการณ์ไม่ดีขึ้นเลยอ่ะนี่มันก็หลายวันแล้วนะยังไม่เห็นคนอุบลได้รับความช่วยเหลืออย่างทั่วถึงเลยเห็นแ',
#  'ก็ยังจะถามคำเดิมน้ำผันลงเขื่อนปากมูนวันละกี่ล้านลบมทำไมมวลน้ำมีแต่เพิ่มขึ้นทุกวันชลประทานต้องให้คำตอบในเรื่อง',
#  'ก็ยังจะถามคำเดิมน้ำผันลงเขื่อนปากมูนวันละกี่ล้านลบมทำไมมวลน้ำมีแต่เพิ่มขึ้นทุกวันชลประทานต้องให้คำตอบในเรื่องนี้เพราะ',
#  'ขอสอบถามค่ะจากมอุบลไปสนามบินมีเส้นทางไหนที่ยังใช้ได้บ้างคะน้ําท่วมอุบล',
#  'ขอสอบถามค่ะว่าข่าวช่องหลักออกบ้างมั๊ยนี่ไม่ได้ดูข่าวเลยตามแต่ในทวิตแล้วก็ขอให้รัฐออกมาแก้ไขได้แล้วนะคะไม่ใช่นอนน้ำ',
#  'ขออนุญาตขำให้ถึงดาวอังคารรรฮ่าาาๆๆๆๆๆๆ',
#  'ขออนุญาตนะครับทำไมต้องเป็นแบบนี้นะครับระบบมีราชการไว้เปลืองภาษีเท่านั้นปชชเดือดร้อนแหกตาดูสิครับความเดือดร้อนข',
#  'ขออนุญาตนะครับนอกจากอุบลแล้วฝากให้ความช่วยเหลือพี่น้องชาวศรีสะเกษและอยุธยาด้วยนะครับและอีกหลายๆที่ด้วยนะครับ',
#  'ขออนุญาตนะครับน้ําท่วมอยุธยาก็หนักพอกันยาวนานมากด้วยไม่ว่าจะน้ําท่วมอุบลน้ําท่วมมหาสารคามน้ําท่วมศรีสะเกษ',
#  'ขออนุญาตนะคะฝากทุกคนช่วยเค้าดันน้ําท่วมอุบลหน่อยได้มั้ยคะบ้านเค้าเองตอนนี้อุบลเป็นเมืองใต้บาดาลไปแล้วค่ะไม่ได้รับการช่',
#  'ขออภัยที่แซ่บไม่ถึงใจพี่นะเข้าเล่นเกมเข้ากลุ่มลับเข้าก',
#  'ขอเป็นส่วนหนึ่งส่งกำลังใจให้ชาวอุบลผ่านพ้นวิกฤตน้ำท่วมไปได้โดยเร็วและช่วยรีข่าวสารเพื่อเป็นกระบอกเสียงและประโยชน์',
#  'ขอเป็นอีกกระบอกเสียงในการช่วยเหลือประชาชนในภาคตะวันออกเฉียงเหนือภาคเหนือนนทบุรีและอีกหลายพื้นที่ให้บุคคลที่มีส่วนรับผิ',
#  'ขอเป็นแรงที่ช่วยกระจายข่าวขอให้ได้รับความช่วยเหลือจากหน่วยงานที่เกี่ยวข้องให้ไวที่สุดน้ำท่วมอุบล',
#  'ขอโทษนะที่หน้าไม่คมพอดีหน้ากลมแถมจิ้มได้น้ำท่วมนนทบุรีมิลลิผู้จัดไม่ควรเอาเปรียบติ่ง',
#  'ขอโทษนะสื่อต่างๆเงียบจังแทบไม่ได้ยินข่าวน้ำท่วมเลยอะบางสื่อก็ออกนะแต่ไม่ขยี้ให้สุดหน่วยงานภาครัฐทำอะไรอยู่เห็นแ',
#  'ขอให้ชาวอุบลทุกๆพื้นที่ปลอดภัยค่ะน้ำท่วมอุบล',
#  'ขอให้น้ำลดเร็วๆนะคะน้ําท่วมอุบล',
#  'ขอให้น้ำลดไวไว',
#  'ขาลเถาะมะเส็งมะแมระกาหมั่นสร้างบุญกุศลเจ้ากรรมนายเวรกำลังอโหสิกรรมให้ดวงกำลังจะดีขึ้นดูดวงนาคา',
#  'ขาลเถาะมะเส็งมะแมระกาหมั่นสร้างบุญกุศลเจ้ากรรมนายเวรกำลังอโหสิกรรมให้ดวงกำลังจะดีขึ้นดูดวงนาคาเงินกู้',
#  'ขึ้นชื่อว่าหอเตือนภัยถ้าไม่เคือนจะเก็บไว้ทำส้นรองเท้าอะไรอะอิเจ้',
#  'ข่าวคือเงียบมากช่วยกันดันเเท็กหน่อยนะครับช่วยกันเป็นกระบอกเสียงหรือถ้าใครสะดวกบริจาคทรัพย์เช็คให้ดีนะครับทระวังมิจฉาชีพน้ําท่วมอุบล',
#  'ข่าวค่อนข้างเงียบมากกกกรัฐบาลก็ไม่ทำห่าเหวอะไรการช่วยเหลือล่าช้าเนี่ยพรุ่งนี้อิป้อมจะลงพื้นที่เสร่อไปทำไมไปสร้',
#  'ข่าวทีวีเค้าเป็นอะไรกันไม่มีใครไปทำข่าวที่อุบลเหรองงมากออกแต่ข่าวฆ่ากันตายตอนนี้คนอุบลเค้าก็จะตายกันแล้วน้ําท่วมอุบล',
#  'ข่าวน้ำท่วมน้ําท่วมอุบลน้ําท่วมศรีสะเกษ',
#  'ข่าวน้ําท่วมอุบลไม่ค่อยดังเลยนะครับ',
#  'ข่าวเงียบมากกกน้ําท่วมอุบล',
#  'ข่าวเงียบมากถ้าไม่มีต้องนับสต็อคแล้วโทรนัดคนพื้นที่คือไม่รู้ว่าท่วมขนาดนี้อ่ะ',
#  'ค',
#  'คนชอบหวยลองดูครับพี่แจกชื้อฟรีถูกรับไปเลยแอดไลน์แบนมิลลิน้ําท่วมอุบล',
#  'คนที่เคยรู้สึกว่าการล้อเลียนโฆษณาตัวหนึ่งที่มีคนกินข้าวบนหลังคาบ้านท่ามกลางน้ำท่วมหนักเป็นเรื่องตลกผมหวังว่าวั',
#  'คนนี้ความคิดล้มเหลวมากงั้นไม่ต้องเรียกหอเตือนภัยเรียกวิทยุกระจายยเสียงหมู่บ้าน',
#  'คนนึงจะว่ายน้ำข้ามโขงเพียงเพื่อหาเงินบริจาคในขณะที่คนนับแสนกำลังลำบากน้ำท่วมนี่มันอะไรสถานเขายังไม่รู้อีกหรือว่าอะไรสำ',
#  'คนไทยเหมือนชินกับการอยู่ลำบากไปแล้วอ่ะอนทนกันเก่งฉิบหายรอคอยการช่วยจากหน่อยงานที่เกี่ยวข้องการแก้ปัญหาที่ปลายเหตุเสมอท่วม',
#  'ครบจบที่นี่ที่เดียวระบบฝากถอนออโต้บริการตลอดชมสมัครวันนี้รับฟรีโปรโมชั่นอีกมากมายสน',
#  'ครบวงจรด้วยระบบน้ําท่วมอุบลน้ําท่วมอุบลแบนมิลลิโตโน่หม้อไฟแห่งความสุข',
#  'ครั้งก่อนปีรัฐบาลขอรับบริจาคเงินช่วยชาวอุบลจากน้ำท่วมไม่ทราบว่าให้ชาวอุบลหมดยังคะเห็นเงียบๆครั้งนี้จะใ',
#  'ครแก่ที่ต้องหาหมอช่วยตัวเองไม่ได้กู้ภับแบกฝาาน่ำฝนคกใส่รัฐบาลทำอะไรป้อมน่าจะฉุกคิดบ้างว่าขนาดป้อมยัง',
#  'ครแก่ที่ต้องหาหมอช่วยตัวเองไม่ได้กู้ภับแบกฝาาน่ำฝนคกใส่รัฐบาลทำอะไรป้อมน่าจะฉุกคิดบ้างว่าขนาดป้อมยังล้างคูดตั',
#  'ควย',
#  'ความคิดเก่ามาก',
#  'ควายนี่',
#  'คาสิโนดีที่สุดโปรเอาใจคนทุนน้อยรับรับฝากถอนไม่มีขั้นต่ำพร้อมสูตรสล็อตฟรี',
#  'คาเฟ่คาใจหลบน้ำท่วมไปพักกายพักใจที่คาเฟ่แปบคาเฟ่อุบลอุบลหวานมากน้ําท่วมอุบล',
#  'คำถามที่น่าจะไม่ได้คำตอบคือรัฐบาลทำอะไรอยู่มองไม่เห็นสิ่งที่ประชาชนต้องประสบอยู่สักนิดขนาดนี้ได้ยังไงไปมุดหัวอยู่ที่ไหนหมดน้ําท่วมอุบล',
#  'คำเดียวเลยเหี้ย',
#  'คืนนี้กี่น้ำดีมาแล้วสมาชิกใหม่ฝากรับไปเลยฟรีอีกจิ้มลิงค์',
#  'คือจะบอกว่าน้ำไฟถูกตัดขาดก็ไม่ถูกอะมันก็มีบ้านที่ไม่ท่วมแต่บ้านที่ท่วมก็คือโดนตัดไฟไปแล้วแต่มันก็ใช้ชีวิตลำบากจริงๆ',
#  'คือถ้าไม่อวดอ้างก็ว่าจะไม่ด่าพัสดุที่ส่งถึงสนงยุติธรรมจอุบลฯแบบเข้าใจว่าน้ําท่วมอุบลแต่ที่ช็อกไ',
#  'คือปีนี้หนักมากกกกไม่เคยพบเคยเจอล่าสุดเส้นทางหลักเข้าเมืองอุบลน้ำขึ้นสูงท่วมแล้วน้ำก็จะถึงโรงพยาบาลประจำจังหวัดข่าวคือเงียบ',
#  ...]

# %%
# Dict of Labels
label_dict = {'อุบลจะจมบาดาล':0.0,
 'สงสาร':1.0,
 'จมน้ำเสียชีวิต':2.0,
 'น้ำท่วมสูง':3.0}

# %%
df.show()
# Out:
# +--------------------+
# |       Cleaning_Data|
# +--------------------+
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
# |สนใจงานออนไลน์หาร...|
# |งั้นหอเตือนภัยก็ไ...|
# |ที่ดันเเท็กกันอยู...|
# |นี่คือบ้านของเราเ...|
# |อุบลจะจมบาดาลแล้ว...|
# |เมื่อไหร่สำนักข่า...|
# |น้องๆน่าสงสารมากก...|
# |อุบลจะจมบาดาลแล้ว...|
# |อุบลจะจมบาดาลแล้ว...|
# |ฝากรีหน่อยค่ะคุณย...|
# |น้ำท่วมอุบลวันนี้...|
# |นี่คือบ้านของเราเ...|
# |ย้ำตอนนี้น้ำไฟถูก...|
# |ถูกตัดขาดคือแล้วย...|
# |นี่คือบ้านของเราเ...|
# |ไม่ใช่ทางม้าลายแต...|
# |น้องๆน่าสงสารมากก...|
# |งานดีรีวิวแน่นมาก...|
# +--------------------+
# only showing top 20 rows

# %%
df = labelEncoder.transform(df)

# %%
df.show(5)
# Out:
# +--------------------+-----+
# |       Cleaning_Data|label|
# +--------------------+-----+
# |อุบลจะจมบาดาลแล้ว...|  4.0|
# |อุบลจะจมบาดาลแล้ว...|  4.0|
# |สนใจงานออนไลน์หาร...|535.0|
# |งั้นหอเตือนภัยก็ไ...| 44.0|
# |ที่ดันเเท็กกันอยู...|601.0|
# +--------------------+-----+
# only showing top 5 rows

# %%
### Split Dataset
(trainDF,testDF) = df.randomSplit((0.7,0.3),seed=42)

# %%
trainDF.show()
# Out:
# +--------------------+-----+
# |       Cleaning_Data|label|
# +--------------------+-----+
# |กกตควรพิจารณาให้ส...|486.0|
# |กกตควรพิจารณาให้ส...|486.0|
# |กกตยกเลิกวันของสส...|351.0|
# |กกตยกเลิกวันของสส...|351.0|
# |กกตยกเลิกวันของสส...|351.0|
# |กกตยกเลิกวันของสส...|351.0|
# |กฎกกตวันเหี้ยมากท...|283.0|
# |กฎกกตวันเหี้ยมากท...|283.0|
# |กฎกกตวันเหี้ยมากท...|283.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# |กระจายข่าวอุบลตอน...| 98.0|
# +--------------------+-----+
# only showing top 20 rows

# %%
### Estimator
from pyspark.ml.classification import LogisticRegression

# %%
lr = LogisticRegression(featuresCol='vectorizedFeatures',labelCol='label')

# %% [markdown]
# #### Building the Pipeline

# %%
from pyspark.ml import Pipeline

# %%
pipeline = Pipeline(stages=[tokenizer,stopwords_remover,vectorizer,idf,lr])

# %%
pipeline
# Out:
# Pipeline_a83b64b44736

# %%
pipeline.stages
# Out:
# Param(parent='Pipeline_a83b64b44736', name='stages', doc='a list of pipeline stages')

# %%
# Building MOdel
lr_model = pipeline.fit(trainDF)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Input In [39], in <cell line: 2>()
#       1 # Building MOdel
# ----> 2 lr_model = pipeline.fit(trainDF)
#
# File C:\spark\python\pyspark\ml\base.py:205, in Estimator.fit(self, dataset, params)
#     204     else:
# --> 205         return self._fit(dataset)
#     206 else:
#
# File C:\spark\python\pyspark\ml\pipeline.py:134, in Pipeline._fit(self, dataset)
#     133 else:  # must be an Estimator
# --> 134     model = stage.fit(dataset)
#     135     transformers.append(model)
#
# File C:\spark\python\pyspark\ml\base.py:205, in Estimator.fit(self, dataset, params)
#     204     else:
# --> 205         return self._fit(dataset)
#     206 else:
#
# File C:\spark\python\pyspark\ml\wrapper.py:379, in JavaEstimator._fit(self, dataset)
#     378 def _fit(self, dataset: DataFrame) -> JM:
# --> 379     java_model = self._fit_java(dataset)
#     380     model = self._create_model(java_model)
#
# File C:\spark\python\pyspark\ml\wrapper.py:376, in JavaEstimator._fit_java(self, dataset)
#     375 self._transfer_params_to_java()
# --> 376 return self._java_obj.fit(dataset._jdf)
#
# File C:\spark\python\lib\py4j-0.10.9.5-src.zip\py4j\java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#
# File C:\spark\python\pyspark\sql\utils.py:190, in capture_sql_exception.<locals>.deco(*a, **kw)
#     189 try:
# --> 190     return f(*a, **kw)
#     191 except Py4JJavaError as e:
#
# File C:\spark\python\lib\py4j-0.10.9.5-src.zip\py4j\protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#
# <class 'str'>: (<class 'ConnectionRefusedError'>, ConnectionRefusedError(10061, 'No connection could be made because the target machine actively refused it', None, 10061, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:1993, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1990     traceback.print_exc()
#    1991     return None
# -> 1993 self._showtraceback(etype, value, stb)
#    1994 if self.call_pdb:
#    1995     # drop into debugger
#    1996     self.debugger(force=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\zmqshell.py:542, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     536 sys.stdout.flush()
#     537 sys.stderr.flush()
#     539 exc_content = {
#     540     'traceback' : stb,
#     541     'ename' : str(etype.__name__),
# --> 542     'evalue' : str(evalue),
#     543 }
#     545 dh = self.displayhook
#     546 # Send exception info over pub socket for other clients than the caller
#     547 # to pick up
#
# File C:\spark\python\lib\py4j-0.10.9.5-src.zip\py4j\protocol.py:471, in Py4JJavaError.__str__(self)
#     469 def __str__(self):
#     470     gateway_client = self.java_exception._gateway_client
# --> 471     answer = gateway_client.send_command(self.exception_cmd)
#     472     return_value = get_return_value(answer, gateway_client, None, None)
#     473     # Note: technically this should return a bytestring 'str' rather than
#     474     # unicodes in Python 2; however, it can return unicodes for now.
#     475     # See https://github.com/bartdag/py4j/issues/306 for more details.
#
# File C:\spark\python\lib\py4j-0.10.9.5-src.zip\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File C:\spark\python\lib\py4j-0.10.9.5-src.zip\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File C:\spark\python\lib\py4j-0.10.9.5-src.zip\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File C:\spark\python\lib\py4j-0.10.9.5-src.zip\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
lr_model

# %%
# Predictions on our Test Dataset
predictions = lr_model.transform(testDF)

# %%
predictions.show()

# %%
# Select Columns
predictions.columns

# %%
predictions.select('rawPrediction','probability','subject','label','prediction').show(10)

# %%
### Model Evaluation
#+ Accuracy
#+ Precision
#+ F1score
#+ etc

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
evaluator = MulticlassClassificationEvaluator(labelCol='label',predictionCol='prediction',metricName='accuracy')

# %%
accuracy = evaluator.evaluate(predictions)

# %%
accuracy

# %%
#### Method 2: Precision. F1Score (Classification Report)
from pyspark.mllib.evaluation import MulticlassMetrics

# %%
lr_metric = MulticlassMetrics(predictions['label','prediction'].rdd)

# %%
print("Accuracy:",lr_metric.accuracy)
print("Precision:",lr_metric.precision(1.0))
print("Recall:",lr_metric.recall(1.0))
print("F1Score:",lr_metric.fMeasure(1.0))

# %% [markdown]
# ### Confusion Matrix
# + convert to pandas
# + sklearn

# %%
y_true = predictions.select('label')
y_true = y_true.toPandas()
y_pred = predictions.select('prediction')
y_pred = y_pred.toPandas()

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(y_true,y_pred)

# %%
cm

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
label_dict.keys()

# %%
class_names = ['Web Development', 'Business Finance', 'Musical Instruments', 'Graphic Design','N4','N5']

# %%
plot_confusion_matrix(cm,class_names)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Classication Report
print(classification_report(y_true,y_pred))

# %%
# Classication Report
print(classification_report(y_true,y_pred,target_names=class_names))

# %%
class_temp = predictions.select("label").groupBy("label")\
                        .count().sort('count', ascending=False).toPandas()
class_temp = class_temp["label"].values.tolist()
class_names = map(str, class_temp)
# # # print(class_name)
class_names

# %% [markdown]
# ### Making Single Prediction
# + sample as DF
# + apply pipeline

# %%
from pyspark.sql.types import StringType

# %%
ex1 = spark.createDataFrame([
    ("Building Machine Learning Apps with Python and PySpark",StringType())
],
# Column Name
["course_title"]

)

# %%
ex1.show()

# %%
# Show Full 
ex1.show(truncate=False)

# %%
# Predict
pred_ex1 = lr_model.transform(ex1)

# %%
pred_ex1.show()

# %%
pred_ex1.columns

# %%
pred_ex1.select('course_title','rawPrediction','probability','prediction').show()

# %%
label_dict

# %%
### Save and Load Model

# %%
# Saving Model
modelPath = "models/pyspark_lr_model_26_Feb_2021"
lr_model.save(modelPath)

# %%
# Loading pickled model via pipeline api
from pyspark.ml.pipeline import PipelineModel
persistedModel = PipelineModel.load(modelPath)

# %%
modelPath

# %%
lr_model

# %%
lr_model.save(modelPath)
